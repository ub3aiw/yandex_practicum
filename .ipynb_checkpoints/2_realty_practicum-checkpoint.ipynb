# %% [markdown]
# ### <font color='green'>Комментарий от наставника 1
# Олег, привет! Спасибо, что учёл мои замечания из прошлого проекта :) <br>
# Как и прежде ищи мои комментарии в подобных ячейках. Пункты, где всё отлично, я отмечаю галкой <span style="color:green;font-size:200%">&#10003;</span> или <font color='green'><b>зелёным комментарием</b></font>. Там, где нужно что-то исправить для привлечения внимания я пишу другими цветами (зависят от итерации). Начну с <font color='red'><b>красного</b></font> :)

# %% [markdown]
# <font color='orange'> Привет, Ира! Спасибо и тебе -- за дельные замечания и за то, что так оперативно проверила мою работу, хотя я затянул со сдачей (в этот раз было посложнее, чем в первый).

# %% [markdown]
# ### <font color='blue'>Комментарий от наставника 1 итерация 2
# Спасибо за исправления! Да, многие говорят, что в этот раз проект несколько сложнее, но ничего, ты отлично справляешься!
#
# Как обычно пометила тегом <span style="color:green;font-size:200%">&#10003;</span> те исправления, где всё отлично. Свои новые комментарии выделила синим цветом, чтобы можно было их отличить от старых комментариев.

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# Нам предстоит исследовать рынок жилой недвижимости Санкт-Петербурга и его окрестностей с тем, чтобы выявить закономерности, которые могут пригодится для определения рыночной цены квартир и автоматического отслеживания аномалий.
#
# ### Загрузка данных и первое знакомство с ними <span style="color:green;font-size:200%">&#10003;</span>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 24 columns):
# building_series_id      6517 non-null object
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# area                    23699 non-null float64
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# parks_nearest           8079 non-null float64
# ponds_around3000        18181 non-null float64
# ponds_nearest           9110 non-null float64
# days_exposition         20518 non-null float64
# dtypes: bool(2), float64(15), int64(3), object(4)
# memory usage: 4.0+ MB

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor          area  kitchen_area  \
# count  23613.000000  21796.000000  23699.000000  23699.000000  21421.000000
# mean      10.673824     34.457852      5.892358     60.348651     10.569807
# std        6.597173     22.030445      4.885249     35.654083      5.905438
# min        1.000000      2.000000      1.000000     12.000000      1.300000
# 25%        5.000000     18.600000      2.000000     40.000000      7.000000
# 50%        9.000000     30.000000      4.000000     52.000000      9.100000
# 75%       16.000000     42.300000      8.000000     69.900000     12.000000
# max       60.000000    409.700000     33.000000    900.000000    112.000000
#
#             balcony  airports_nearest  cityCenters_nearest  parks_around3000  \
# count  12180.000000      18157.000000         18180.000000      18181.000000
# mean       1.150082      28793.672193         14191.277833          0.611408
# std        1.071300      12630.880622          8608.386210          0.802074
# min        0.000000          0.000000           181.000000          0.000000
# 25%        0.000000      18585.000000          9238.000000          0.000000
# 50%        1.000000      26726.000000         13098.500000          0.000000
# 75%        2.000000      37273.000000         16293.000000          1.000000
# max        5.000000      84869.000000         65968.000000          3.000000
#
#        parks_nearest  ponds_around3000  ponds_nearest  days_exposition
# count    8079.000000      18181.000000    9110.000000     20518.000000
# mean      490.804555          0.770255     517.980900       180.888634
# std       342.317995          0.938346     277.720643       219.727988
# min         1.000000          0.000000      13.000000         1.000000
# 25%       288.000000          0.000000     294.000000        45.000000
# 50%       455.000000          1.000000     502.000000        95.000000
# 75%       612.000000          1.000000     729.000000       232.000000
# max      3190.000000          3.000000    1344.000000      1580.000000

# %%
data.head()
# Out:
#   building_series_id  total_images  last_price  total_area  \
# 0            1564812            20  13000000.0       108.0
# 1                NaN             7   3350000.0        40.4
# 2         Сталинский            10   5196000.0        56.0
# 3                NaN             0  64900000.0       159.0
# 4                NaN             2  10000000.0       100.0
#
#   first_day_exposition  rooms  ceiling_height  floors_total  living_area  \
# 0  2019-03-07T00:00:00      3            2.70          16.0         51.0
# 1  2018-12-04T00:00:00      1             NaN          11.0         18.6
# 2  2015-08-20T00:00:00      2             NaN           5.0         34.3
# 3  2015-07-24T00:00:00      3             NaN          14.0          NaN
# 4  2018-06-19T00:00:00      2            3.03          14.0         32.0
#
#    floor  ... kitchen_area  balcony    locality_name  airports_nearest  \
# 0      8  ...         25.0      NaN  Санкт-Петербург           18863.0
# 1      1  ...         11.0      2.0   посёлок Шушары           12817.0
# 2      4  ...          8.3      0.0  Санкт-Петербург           21741.0
# 3      9  ...          NaN      0.0  Санкт-Петербург           28098.0
# 4     13  ...         41.0      NaN  Санкт-Петербург           31856.0
#
#    cityCenters_nearest  parks_around3000 parks_nearest  ponds_around3000  \
# 0              16028.0               1.0         482.0               2.0
# 1              18603.0               0.0           NaN               0.0
# 2              13933.0               1.0          90.0               2.0
# 3               6800.0               2.0          84.0               3.0
# 4               8098.0               2.0         112.0               1.0
#
#    ponds_nearest  days_exposition
# 0          755.0              NaN
# 1            NaN             81.0
# 2          574.0            558.0
# 3          234.0            424.0
# 4           48.0            121.0
#
# [5 rows x 24 columns]

# %%
data.sample(20)
# Out:
#       building_series_id  total_images  last_price  total_area  \
# 2945             1564801            20   7300000.0        60.6
# 9630                 NaN            14   3150000.0        59.1
# 17195                NaN            15  16200000.0       118.0
# 2554           1569038.0            13   4300000.0        46.0
# 21292                NaN            10   2700000.0        30.0
# 5                    NaN            10   2890000.0        30.4
# 976                  NaN             2   6400000.0        62.0
# 16801                NaN            17  12399000.0        63.4
# 15805                NaN             8   4700000.0        38.0
# 16906                NaN            13   4250000.0        39.0
# 23077                NaN            10  12500000.0       107.0
# 21505                NaN             9   4100000.0        35.3
# 3246                 NaN            16   5099000.0        51.2
# 17765                NaN             6   6150000.0        73.0
# 11987          1564812.0            20   4200000.0        34.9
# 12978                NaN            12   4150000.0        34.0
# 9460                 NaN             1   2950000.0        45.0
# 16041                NaN             2   3290000.0        44.0
# 10654          1564812.0            18  29900000.0        74.4
# 23071                NaN             6   5100000.0        51.7
#
#       first_day_exposition  rooms  ceiling_height  floors_total  living_area  \
# 2945   2019-03-23T00:00:00      3            2.50           9.0         39.0
# 9630   2015-11-24T00:00:00      2            2.65           5.0         29.9
# 17195  2014-12-11T00:00:00      4             NaN           6.0         87.0
# 2554   2018-02-07T00:00:00      2            2.50           5.0         30.0
# 21292  2016-04-20T00:00:00      1            2.50           9.0         15.0
# 5      2018-09-10T00:00:00      1             NaN          12.0         14.4
# 976    2017-07-21T00:00:00      3            2.50          12.0         40.0
# 16801  2018-10-22T00:00:00      2             NaN          16.0         32.5
# 15805  2018-01-23T00:00:00      1            3.00          15.0         17.5
# 16906  2017-08-11T00:00:00      1            2.55           5.0         17.8
# 23077  2017-09-25T00:00:00      4             NaN           5.0          NaN
# 21505  2018-01-10T00:00:00      1            2.75          27.0          8.5
# 3246   2018-02-08T00:00:00      2            2.50           5.0         30.1
# 17765  2016-03-05T00:00:00      4             NaN           9.0         49.0
# 11987  2019-02-28T00:00:00      1            2.50          12.0         19.4
# 12978  2017-08-29T00:00:00      1             NaN           9.0         20.0
# 9460   2017-11-22T00:00:00      2            2.60           5.0         30.2
# 16041  2016-02-02T00:00:00      1             NaN          20.0         21.5
# 10654  2018-12-13T00:00:00      2            4.00           4.0         49.0
# 23071  2016-05-11T00:00:00      2            2.70          12.0         37.1
#
#        floor  ... kitchen_area  balcony              locality_name  \
# 2945       8  ...          6.0      5.0            Санкт-Петербург
# 9630       1  ...          8.3      NaN                   Коммунар
# 17195      6  ...         12.0      0.0            Санкт-Петербург
# 2554       2  ...          6.4      1.0            Санкт-Петербург
# 21292      3  ...          7.5      0.0            Санкт-Петербург
# 5          5  ...          9.1      NaN  городской посёлок Янино-1
# 976        3  ...          9.5      5.0            Санкт-Петербург
# 16801      7  ...          NaN      NaN            Санкт-Петербург
# 15805      6  ...         11.4      NaN            Санкт-Петербург
# 16906      5  ...          8.3      0.0            Санкт-Петербург
# 23077      4  ...          NaN      NaN            Санкт-Петербург
# 21505     11  ...         16.1      2.0            Санкт-Петербург
# 3246       4  ...          6.8      NaN            Санкт-Петербург
# 17765      9  ...          6.0      0.0            Санкт-Петербург
# 11987      5  ...          6.9      NaN            Санкт-Петербург
# 12978      7  ...          NaN      0.0            Санкт-Петербург
# 9460       1  ...          7.2      NaN       село Русско-Высоцкое
# 16041      5  ...          9.8      2.0    деревня Новое Девяткино
# 10654      3  ...         11.1      1.0            Санкт-Петербург
# 23071      2  ...          6.6      0.0            Санкт-Петербург
#
#        airports_nearest  cityCenters_nearest  parks_around3000 parks_nearest  \
# 2945            49684.0              15996.0               0.0           NaN
# 9630                NaN                  NaN               NaN           NaN
# 17195           24584.0               3378.0               2.0         537.0
# 2554            27216.0               8195.0               0.0           NaN
# 21292           19559.0              18561.0               1.0         672.0
# 5                   NaN                  NaN               NaN           NaN
# 976             28313.0              13188.0               1.0         470.0
# 16801           39474.0              12650.0               1.0          96.0
# 15805           33531.0              12163.0               0.0           NaN
# 16906           12210.0              11797.0               0.0           NaN
# 23077           24190.0               2364.0               2.0         287.0
# 21505           33977.0              15076.0               0.0           NaN
# 3246            39524.0              11090.0               1.0         379.0
# 17765           32920.0              11695.0               0.0           NaN
# 11987           50477.0              13252.0               2.0         220.0
# 12978           10522.0              12601.0               1.0         440.0
# 9460                NaN                  NaN               NaN           NaN
# 16041               NaN                  NaN               NaN           NaN
# 10654           23671.0                639.0               3.0         455.0
# 23071           12626.0              13170.0               0.0           NaN
#
#        ponds_around3000  ponds_nearest  days_exposition
# 2945                0.0            NaN              NaN
# 9630                NaN            NaN           1231.0
# 17195               1.0          719.0            719.0
# 2554                0.0            NaN             88.0
# 21292               1.0          524.0            432.0
# 5                   NaN            NaN             55.0
# 976                 1.0           20.0             65.0
# 16801               0.0            NaN             23.0
# 15805               0.0            NaN            130.0
# 16906               0.0            NaN             85.0
# 23077               3.0          467.0            229.0
# 21505               0.0            NaN             60.0
# 3246                1.0          486.0            110.0
# 17765               0.0            NaN            244.0
# 11987               1.0         1250.0             35.0
# 12978               1.0          809.0             68.0
# 9460                NaN            NaN              6.0
# 16041               NaN            NaN            201.0
# 10654               3.0          345.0              NaN
# 23071               0.0            NaN            111.0
#
# [20 rows x 24 columns]

# %%
data.tail()
# Out:
#       building_series_id  total_images  last_price  total_area  \
# 23694          1564812.0             9   9700000.0      133.81
# 23695                NaN            14   3100000.0       59.00
# 23696                NaN            18   2500000.0       56.70
# 23697                NaN            13  11475000.0       76.75
# 23698                NaN             4   1350000.0       32.30
#
#       first_day_exposition  rooms  ceiling_height  floors_total  living_area  \
# 23694  2017-03-21T00:00:00      3             3.7           5.0         73.3
# 23695  2018-01-15T00:00:00      3             NaN           5.0         38.0
# 23696  2018-02-11T00:00:00      2             NaN           3.0         29.7
# 23697  2017-03-28T00:00:00      2             3.0          17.0          NaN
# 23698  2017-07-21T00:00:00      1             2.5           5.0         12.3
#
#        floor  ... kitchen_area  balcony        locality_name  \
# 23694      3  ...        13.83      NaN      Санкт-Петербург
# 23695      4  ...         8.50      NaN                Тосно
# 23696      1  ...          NaN      NaN     село Рождествено
# 23697     12  ...        23.30      2.0      Санкт-Петербург
# 23698      1  ...         9.00      NaN  поселок Новый Учхоз
#
#        airports_nearest  cityCenters_nearest  parks_around3000 parks_nearest  \
# 23694           24665.0               4232.0               1.0         796.0
# 23695               NaN                  NaN               NaN           NaN
# 23696               NaN                  NaN               NaN           NaN
# 23697           39140.0              10364.0               2.0         173.0
# 23698               NaN                  NaN               NaN           NaN
#
#        ponds_around3000  ponds_nearest  days_exposition
# 23694               3.0          381.0              NaN
# 23695               NaN            NaN             45.0
# 23696               NaN            NaN              NaN
# 23697               3.0          196.0            602.0
# 23698               NaN            NaN              NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# В таблице много пропусков, и не все из них можно заполнить правдоподобными значениями, которые не исказят датасет. Например, вряд ли получится с помощью простых расчетов в pandas корректно заполнить недостающие расстояния до прудов, парков, аэропортов и центров городов. Или сериии домов. Если все строки с пропущенными значениями удалить, от датасета ничего не останется в прямом смысле. Если заполнить пропуски техническими значениями (допустим, -1), исказятся многие расчеты. Если оставить все как есть, не будут строиться некоторые графики (например, `boxplot`). Но последнюю проблему можно обойти, если строить график по срезу. Поэтому пропуски в столбцах типа `object` заполним словом 'неизвестно', а численные столбцы оставим как есть. Недостающие данные в `living_area` и `kitchen_area` можно было бы восстановить, опираясь на `total_area`, но данных во всех столбцах хватает и так, поэтому делать этого не будем.
#
# Некоторые крайние значения явно ошибочны. Это касается минимального и максимального в `ceiling_height`, минимального в `last_price`. Их нужно отсеять в ходе предобработки.
#
# Другие выглядят хоть и правдоподобно, но подозрительно: например, максимальное в `kitchen_area`. В задании сказано, что нас интересуют "типичные" параметры продаваемых квартир, поэтому эти выбросы мы учитывать не будем, но не станем и удалять их (на случай если они пригодятся для другого исследования), а отфильтруем на этапе анализа.

# %% [markdown]
# ### <font color='green'>Комментарий от наставника 2
# Лайк!

# %% [markdown]
# ### Предобработка данных <span style="color:green;font-size:200%">&#10003;</span>

# %% [markdown]
# В датасете есть два столбца, значения в которых на вид одинаковые. Проверим, совпадают ли они полностью, и если да, один из столбцов удалим.

# %%
data['total_area'].equals(data['area'])
# Out:
# True

# %%
data.drop(columns='area', inplace=True)

# %% [markdown]
# Преобразуем данные в столбце с датой выставления квартиры на продажу в формат `datetime`.

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'])

# %% [markdown]
# Судя по названию, столбец `is_apartment` должен содержать данные булева типа, но почему-то там `object`. Посмотрим, какие значения в нем встречаются, и если догадка верна, преобразуем в `bool`, исходя из того, что пропуски соответствуют значению `False` (предположим, что в несовершенном пользовательском интерфейсе была не одна галочка, которой можно было обозначить, что квартира относится к типу апартаментов, а два поля -- да, апартаменты и нет, не апартаменты, и владельцы обычных квартир при заполнении анкеты просто игнорировали оба).

# %%
data.is_apartment.unique()
# Out:
# array([nan, False, True], dtype=object)

# %%
data.is_apartment.fillna(0, inplace=True)
data.is_apartment = data.is_apartment.astype('bool')
data.is_apartment.unique()
# Out:
# array([False,  True])

# %% [markdown]
# Очистим датасет от возможных дубликатов и приведем все строковые столбцы к нижнему регистру.

# %%
data = data.drop_duplicates()
data.building_series_id = data.building_series_id.str.lower()
data.locality_name = data.locality_name.str.lower()

# %% [markdown]
# Предположим, что пропущенные значения в столбце `balcony` имеют ту же природу, что и в столбце `is_apartment`, и их корректно заполнить нулями.

# %%
data.balcony.fillna(0, inplace=True)

# %% [markdown]
# Очистим `last_price` от явно ошибочных значений. Для этого отсортируем таблицу по этому столбцу.

# %%
data.sort_values(by='last_price').head()
# Out:
#       building_series_id  total_images  last_price  total_area  \
# 8793           1564812.0             7     12190.0       109.0
# 17456                NaN             7    430000.0        30.4
# 14911                NaN             5    430000.0        54.0
# 16274                NaN            18    440000.0        40.0
# 17676                NaN             0    450000.0        36.5
#
#       first_day_exposition  rooms  ceiling_height  floors_total  living_area  \
# 8793            2019-03-20      2            2.75          25.0         32.0
# 17456           2019-04-22      1             NaN           2.0         16.0
# 14911           2018-06-26      2             NaN           3.0          NaN
# 16274           2018-07-10      1             NaN           5.0          NaN
# 17676           2018-02-01      1             NaN           5.0         17.3
#
#        floor  ...  kitchen_area  balcony          locality_name  \
# 8793      25  ...          40.5      0.0        санкт-петербург
# 17456      1  ...           6.0      0.0                 сланцы
# 14911      3  ...           NaN      0.0  посёлок станции свирь
# 16274      1  ...           NaN      0.0     деревня старополье
# 17676      4  ...           8.5      1.0      деревня ям-тесово
#
#        airports_nearest  cityCenters_nearest parks_around3000  parks_nearest  \
# 8793            36421.0               9176.0              1.0          805.0
# 17456               NaN                  NaN              NaN            NaN
# 14911               NaN                  NaN              NaN            NaN
# 16274               NaN                  NaN              NaN            NaN
# 17676               NaN                  NaN              NaN            NaN
#
#        ponds_around3000  ponds_nearest  days_exposition
# 8793                0.0            NaN              8.0
# 17456               NaN            NaN              NaN
# 14911               NaN            NaN             44.0
# 16274               NaN            NaN             45.0
# 17676               NaN            NaN            120.0
#
# [5 rows x 23 columns]

# %% [markdown]
# Явно ошибочное (или сознательно искаженное) значение обнаружилось только одно: это двушка площадью больше ста квадратных метров за 12 тыс. рублей. Возможно, кто-то пытался таким образом поднять свое объявление в поисковой выдаче. Удалим эту строку из датасета и посмотрим, что там с высотой потолков.

# %%
data.drop(labels=8793, inplace=True)
data.boxplot('ceiling_height')

# %% [markdown]
# На отшибе оказался тот самый 100-метровый потолок, который мы видели еще при первом вызове `describe()`. Есть и другие выбросы, но они не похожи на ошибочные значения (может быть, под жилье продают какие-нибудь заводские помещения или дворцы с потолками по 30 м), поэтому их удалять их не будем. Посмотрим на аномальные значения снизу.

# %%
data.boxplot('ceiling_height')
plt.ylim(0, 4)
# Out:
# (0, 4)

# %% [markdown]
# Значения ниже нижнего уса явно ошибочные. Удалим их и строку квартиры со 100-метровым потолком.

# %%
data = data.query('ceiling_height != 100 or ceiling_height > 2.2')

# %% [markdown]
# Добавим в таблицу несколько столбцов, которые пригодятся нам для дальнейшего анализа.

# %%
data['price_per_meter'] = data.apply(lambda row: row.last_price / row.total_area, axis=1) # цена за квадратный метр
data['weekday_posted'] = data.first_day_exposition.dt.weekday # в какой день недели была выставлена на продажу
data['month_posted'] = data.first_day_exposition.dt.month # ...месяц...
data['year_posted'] = data.first_day_exposition.dt.year # ...год...
data['living_total_ratio'] = data.apply(lambda row: row.living_area / row.total_area, axis=1) # жилая площадь к общей
data['kitchen_total_ratio'] = data.apply(lambda row: row.kitchen_area / row.total_area, axis=1) # кухонная площадь к общей


def define_floor_type(row):
    if row['floor'] == 1:
        return 'первый'
    # если дом одноэтажный, будем считать, что квартира в нем находится на первом этаже, а не на последнем
    if (row['floors_total'] > 1) & (row['floors_total'] - row['floor'] == 0):
        return 'последний'
    return 'другой'


data['floor_type'] = data.apply(define_floor_type, axis=1) # тип этажа -- первый, последний или ни то, ни то

# %% [markdown]
# Сделаем перекрестную проверку данных о расстояниях до парков/прудов и их численности, а также о площадях и этажности, чтобы убедиться, что в данных нет противоречий. <span style="color:green;font-size:200%">&#10003;</span>

# %%
print(len(data.query('ponds_nearest <= 3000').query('ponds_around3000 < 1')))
print(len(data.query('ponds_around3000 > 0').query('ponds_nearest > 3000')))
print(len(data.query('parks_nearest <= 3000').query('parks_around3000 < 1')))
print(len(data.query('parks_around3000 > 0').query('parks_nearest > 3000')))
print(len(data.query('kitchen_area > total_area')))
print(len(data.query('living_area > total_area')))
print(len(data.query('floor > floors_total')))
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %% [markdown]
# Осталось заполнить оставшиеся пропуски маркерами и переименовать ради единообразия один столбец -- и можно считать предобработку данных завершенной.

# %%
data.building_series_id.fillna('неизвестно', inplace=True)
data.locality_name.fillna('неизвестно', inplace=True)
data.rename(columns={'is_apartment': 'apartment'}, inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23698 entries, 0 to 23698
# Data columns (total 30 columns):
# building_series_id      23698 non-null object
# total_images            23698 non-null int64
# last_price              23698 non-null float64
# total_area              23698 non-null float64
# first_day_exposition    23698 non-null datetime64[ns]
# rooms                   23698 non-null int64
# ceiling_height          14503 non-null float64
# floors_total            23612 non-null float64
# living_area             21795 non-null float64
# floor                   23698 non-null int64
# apartment               23698 non-null bool
# studio                  23698 non-null bool
# open_plan               23698 non-null bool
# kitchen_area            21420 non-null float64
# balcony                 23698 non-null float64
# locality_name           23698 non-null object
# airports_nearest        18156 non-null float64
# cityCenters_nearest     18179 non-null float64
# parks_around3000        18180 non-null float64
# parks_nearest           8078 non-null float64
# ponds_around3000        18180 non-null float64
# ponds_nearest           9110 non-null float64
# days_exposition         20517 non-null float64
# price_per_meter         23698 non-null float64
# weekday_posted          23698 non-null int64
# month_posted            23698 non-null int64
# year_posted             23698 non-null int64
# living_total_ratio      21795 non-null float64
# kitchen_total_ratio     21420 non-null float64
# floor_type              23698 non-null object
# dtypes: bool(3), datetime64[ns](1), float64(17), int64(6), object(3)
# memory usage: 5.1+ MB

# %% [markdown]
# ### <font color='red'>Комментарий от наставника 3
# Очень хорошо! Единственное, я бы ещё привела явно целочисленные параметры (такие как floors_total и ponds_around3000) к типу int.

# %% [markdown]
# <font color='orange'> Пробовал. Не получается из-за NaN, которые ни удалять, ни заполнять не хочется (я описал причины в первом разделе). Как обойти эту проблему, пока не придумал.

# %% [markdown]
# ### <font color='blue'>Комментарий от наставника 2 итерация 2 <span style="color:green;font-size:200%">&#10003;</span>
# Тебе тут поможет небольшая магия (функция dropna). При её применении у нас не искажается индекс, поэтому с операцией присваивания всё хорошо и мы заполняем только те строки, которые хотим, а остальные с NaN остаются без изменений:<br>
# `df['floors_total'] = df['floors_total'].dropna().astype('int')`

# %%
to_int = ['balcony', 'floors_total']
data[to_int] = data[to_int].dropna().astype('int')

# %% [markdown]
# ### Анализ данных

# %% [markdown]
# Нам нужно выделить типичные значения наиболее важных параметров продаваемых квартир -- цены (абсолютной и в пересчете на квадратный метр), общей площади, количества комнат. Для этого создадим функцию, которая построит диаграмму размаха для каждого значимого параметра и отфильтрует датасет, исключая из него выбросы.

# %%
data_filtered = data

# %%
def make_boxplot(df, labels):
    num_rows_before = df.shape[0]
    for label in labels:
        q1 = df[label].describe()['25%']
        q3 = df[label].describe()['75%']
        upper_whisker = q3 + 1.5*(q3 - q1)
        lower_whisker = q1 - 1.5*(q3 - q1)
        if lower_whisker < 0:
            lower_whisker = 0
        if lower_whisker < df[label].min():
            lower_whisker = df[label].min()
        
        df.boxplot(label)
        plt.ylim(lower_whisker, upper_whisker)
        plt.show()
        print('Нормальные значения: от', lower_whisker, 'до', upper_whisker)
        df = df.loc[((df[label] >= lower_whisker) & (df[label] <= upper_whisker)) | (df[label].isnull())]
        print('В датасете осталось', len(df), 'строк')
        
    num_rows_after = df.shape[0]
    print('Количество строк в датафрейме сократилось на', num_rows_before - num_rows_after)
    return df       

data_filtered = make_boxplot(data_filtered, ['last_price', 'price_per_meter', 'total_area', 'rooms', 'ceiling_height'])
# Out:
# Нормальные значения: от 430000.0 до 11900000.0
# В датасете осталось 21664 строк
# Нормальные значения: от 22448.350261219937 до 161231.68109209772
# В датасете осталось 21120 строк
# Нормальные значения: от 13.0 до 101.5
# В датасете осталось 20700 строк
# Нормальные значения: от 0 до 6.0
# В датасете осталось 20700 строк
# Нормальные значения: от 2.125 до 3.125
# В датасете осталось 20095 строк
# Количество строк в датафрейме сократилось на 3603

# %% [markdown]
# В выборку попали крохотные квартиры общей площадью от 13 кв. м -- наверное, какие-нибудь мансарды. Оснований отбраковывать их у нас нет: они находятся между усами, во время предобработки столбцы с площадями были проверены на непротиворечивость.
#
# Нулевые значения в столбце rooms можно принять за ошибку, но если посмотреть на соответствующие значения в столбцах `open_plan` и `studio`, становится ясно, что нули здесь появляются тогда и только тогда, когда квартира принадлежит к одному из двух этих типов, для которых характерно объединение жилого пространства с кухней.

# %%
aux_data = data[['rooms', 'studio', 'open_plan']].query('rooms == 0')
aux_data['studio'].sum() + aux_data['open_plan'].sum() == len(aux_data)
# Out:
# True

# %% [markdown]
# Посмотрим, за сколько дней квартиры обычно продаются (но фильтровать датасет по этому признаку не будем, так как слишком велика вероятность, что аномалии связаны с внешними факторами, а не со свойствами самих квартир).

# %%
data_filtered.boxplot('days_exposition')
plt.ylim(0, 480)
# Out:
# (0, 480)

# %% [markdown]
# ### <font color='red'>Комментарий от наставника 4 <span style="color:green;font-size:200%">&#10003;</span>
# Твой способ убирания выбросов очень хорош, молодец!<br>
# Единственный момент. Давай обратим внимание на то, что ты по сути следовал одному алгоритму - отфильтровывал строки со значениями, которые были выше и ниже "усов" на графике boxplot. Насколько я понимаю, ты каждый раз пороги подбирал руками, тратя на это своё время :) Представь, что завтра нам дадут другой аналогичный датасет (расширенный, например), и придётся делать всё то же самое руками заново.<br>
# Давай будем учиться писать такой код, который затем будет просто переиспользовать!
#
# Для этого я предлагаю взглянуть на изображение ниже и понять, как нам можно технически, не руками, достать границы наших усов.
#
# Q1 и Q3 - это первая и третья квантили, т.е. перцентили 25% и 75% соответственно.<br>
# Т.е. их можно вытащить из describe, вот так, например: `q1 = data_filtered["days_exposition"].describe()["25%"]`.<br>
# Тебе нужны границы усов, которые находятся не сложно по формуле с картинки :)
#
# Когда мы научимся выполнять такую фильтрацию по усам для одного параметра, останется сделать это всё в цикле. Т.е. я предлагаю нам "автоматизировать" нашу фильтрацию, строя в цикле соответствующие графики и выполняя соответствующие фильтрации. Цикл будет по выбранным нами колонкам.
#
# ![Boxplot explanation](https://habrastorage.org/files/d0f/f53/8d5/d0ff538d59154901b18a98469de07fde.png)

# %% [markdown]
# <font color='orange'> Сделал. Так действительно значительно лучше.

# %% [markdown]
# ### <font color='green'>Комментарий от наставника 3 итерация 2
# Отлично!

# %%
data_filtered.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  20095.000000  2.009500e+04  20095.000000  20095.000000    11935.000000
# mean       9.647176  4.684487e+06     51.694040      1.883901        2.645396
# std        5.518549  2.033255e+06     16.691967      0.866245        0.151468
# min        0.000000  6.500000e+05     13.000000      0.000000        2.200000
# 25%        6.000000  3.300000e+06     38.500000      1.000000        2.500000
# 50%        9.000000  4.300000e+06     48.000000      2.000000        2.600000
# 75%       13.000000  5.700000e+06     62.000000      3.000000        2.740000
# max       50.000000  1.190000e+07    101.400000      6.000000        3.120000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  20026.000000  18532.000000  20095.000000  18170.000000  20026.000000
# mean      11.014881     29.532512      6.004081      9.429256      0.607810
# std        6.657213     12.033028      4.959484      3.595104      0.945658
# min        1.000000      2.000000      1.000000      1.300000      0.000000
# 25%        5.000000     18.000000      2.000000      7.000000      0.000000
# 50%        9.000000     29.000000      4.000000      8.900000      0.000000
# 75%       16.000000     38.000000      8.000000     11.000000      1.000000
# max       60.000000     88.000000     33.000000     50.000000      5.000000
#
#        ...  parks_nearest  ponds_around3000  ponds_nearest  days_exposition  \
# count  ...    5962.000000      14935.000000    7015.000000      17746.00000
# mean   ...     493.606005          0.676733     535.961654        169.64623
# std    ...     330.159560          0.863189     275.840620        208.13095
# min    ...       1.000000          0.000000      16.000000          1.00000
# 25%    ...     298.000000          0.000000     324.000000         43.00000
# 50%    ...     459.000000          0.000000     523.000000         90.00000
# 75%    ...     617.000000          1.000000     745.000000        214.00000
# max    ...    3190.000000          3.000000    1344.000000       1580.00000
#
#        price_per_meter  weekday_posted  month_posted   year_posted  \
# count     20095.000000    20095.000000  20095.000000  20095.000000
# mean      91263.905535        2.575765      6.389351   2017.385220
# std       26746.784866        1.797452      3.491887      1.016315
# min       22458.628842        0.000000      1.000000   2014.000000
# 25%       74740.285416        1.000000      3.000000   2017.000000
# 50%       92307.692308        3.000000      6.000000   2017.000000
# 75%      108402.192448        4.000000     10.000000   2018.000000
# max      161192.214112        6.000000     12.000000   2019.000000
#
#        living_total_ratio  kitchen_total_ratio
# count        18532.000000         18170.000000
# mean             0.563141             0.190172
# std              0.103084             0.069969
# min              0.038462             0.043524
# 25%              0.493047             0.136771
# 50%              0.566151             0.176810
# 75%              0.635039             0.235294
# max              1.000000             0.787879
#
# [8 rows x 23 columns]

# %% [markdown]
# Разница между средним и медианным значениями для большинства колонок существенно уменьшилась. Вот самые важные из типичных параметров продаваемых квартир:
# * количество комнат до 6, в среднем чуть меньше 2
# * общая площадь от 13 до 102 кв. м, в среднем 53 кв. м
# * цена за квадратный метр от 22 до 162 тыс. рублей, среднее и медианное значения -- 92 и 93 тыс.
# * стоимость за всю квартиру от 0,65 до 17,9 млн рублей
# * в норме квартира проводит на рынке не более 480 дней, а половина всех квартир продается быстрее, чем за 100 дней

# %% [markdown]
# Какие факторы больше всего влияют на цену квартир? Чтобы ответить на этот вопрос, изучим матрицу корреляций `last_price`.

# %%
data_filtered.corr().loc['last_price'].reset_index().sort_values('last_price', ascending=False)
# Out:
#                   index  last_price
# 1            last_price    1.000000
# 2            total_area    0.708007
# 20      price_per_meter    0.620288
# 6           living_area    0.572382
# 11         kitchen_area    0.463558
# 3                 rooms    0.441092
# 4        ceiling_height    0.407571
# 5          floors_total    0.234498
# 0          total_images    0.163952
# 7                 floor    0.157678
# 17     ponds_around3000    0.113826
# 12              balcony    0.087245
# 15     parks_around3000    0.077837
# 16        parks_nearest    0.064987
# 19      days_exposition    0.056665
# 24   living_total_ratio    0.023355
# 8             apartment    0.019572
# 23          year_posted    0.014727
# 22         month_posted    0.000547
# 21       weekday_posted   -0.008825
# 13     airports_nearest   -0.017189
# 18        ponds_nearest   -0.038984
# 10            open_plan   -0.049114
# 9                studio   -0.075485
# 25  kitchen_total_ratio   -0.128119
# 14  cityCenters_nearest   -0.308743

# %% [markdown]
# Что стоимость квартиры сильно связана с ее площадью и ценой квадратного метра, можно было догадаться и так, а вот менее очевидный факт: стоимость квартиры коррелирует с суммарной площадью комнат в большей степени, чем с площадью кухни или с количеством комнат (коэффициенты Пирсона 0,62, 0,52 и 0,47 соответственно). Все остальные корреляции слишком незначительны, чтобы принимать их во внимание.
#
# Интересно, есть ли корреляции между какими-то другими параметрами квартир? Матрица получится большая, поэтому выведем ее в отсортированном виде.

# %%
pd.set_option('display.max_rows', 1000)
corr_list = data_filtered.corr().unstack()
print(corr_list.where(corr_list != 1).sort_values(ascending=False))
pd.reset_option('display.max_rows')
# Out:
# total_area           living_area            0.902405
# living_area          total_area             0.902405
#                      rooms                  0.895833
# rooms                living_area            0.895833
# total_area           rooms                  0.799897
# rooms                total_area             0.799897
# last_price           total_area             0.708007
# total_area           last_price             0.708007
# floors_total         floor                  0.670821
# floor                floors_total           0.670821
# living_area          living_total_ratio     0.623076
# living_total_ratio   living_area            0.623076
# price_per_meter      last_price             0.620288
# last_price           price_per_meter        0.620288
# kitchen_area         kitchen_total_ratio    0.615903
# kitchen_total_ratio  kitchen_area           0.615903
# rooms                living_total_ratio     0.574065
# living_total_ratio   rooms                  0.574065
# living_area          last_price             0.572382
# last_price           living_area            0.572382
#                      kitchen_area           0.463558
# kitchen_area         last_price             0.463558
# rooms                last_price             0.441092
# last_price           rooms                  0.441092
#                      ceiling_height         0.407571
# ceiling_height       last_price             0.407571
# total_area           kitchen_area           0.402567
# kitchen_area         total_area             0.402567
#                      ceiling_height         0.397022
# ceiling_height       kitchen_area           0.397022
# kitchen_total_ratio  floors_total           0.388331
# floors_total         kitchen_total_ratio    0.388331
# kitchen_area         floors_total           0.374457
# floors_total         kitchen_area           0.374457
#                      price_per_meter        0.373744
# price_per_meter      floors_total           0.373744
#                      kitchen_total_ratio    0.290227
# kitchen_total_ratio  price_per_meter        0.290227
# ceiling_height       total_area             0.275456
# total_area           ceiling_height         0.275456
# price_per_meter      ceiling_height         0.274459
# ceiling_height       price_per_meter        0.274459
# floor                kitchen_total_ratio    0.271523
# kitchen_total_ratio  floor                  0.271523
# floor                price_per_meter        0.266204
# price_per_meter      floor                  0.266204
# ponds_around3000     parks_around3000       0.264961
# parks_around3000     ponds_around3000       0.264961
# kitchen_area         floor                  0.251060
# floor                kitchen_area           0.251060
# airports_nearest     cityCenters_nearest    0.250657
# cityCenters_nearest  airports_nearest       0.250657
# total_area           living_total_ratio     0.248261
# living_total_ratio   total_area             0.248261
# last_price           floors_total           0.234498
# floors_total         last_price             0.234498
# price_per_meter      kitchen_area           0.224665
# kitchen_area         price_per_meter        0.224665
# ceiling_height       kitchen_total_ratio    0.176825
# kitchen_total_ratio  ceiling_height         0.176825
# ceiling_height       floors_total           0.166351
# floors_total         ceiling_height         0.166351
# last_price           total_images           0.163952
# total_images         last_price             0.163952
# floor                last_price             0.157678
# last_price           floor                  0.157678
# balcony              floor                  0.155810
# floor                balcony                0.155810
# floors_total         balcony                0.151419
# balcony              floors_total           0.151419
# ceiling_height       ponds_around3000       0.150324
# ponds_around3000     ceiling_height         0.150324
# living_area          ceiling_height         0.146883
# ceiling_height       living_area            0.146883
# total_images         year_posted            0.146765
# year_posted          total_images           0.146765
# total_images         price_per_meter        0.120312
# price_per_meter      total_images           0.120312
# ceiling_height       parks_around3000       0.120272
# parks_around3000     ceiling_height         0.120272
# ponds_around3000     last_price             0.113826
# last_price           ponds_around3000       0.113826
# total_area           total_images           0.109999
# total_images         total_area             0.109999
# floors_total         parks_nearest          0.108350
# parks_nearest        floors_total           0.108350
# floor                ceiling_height         0.100852
# ceiling_height       floor                  0.100852
# total_images         living_area            0.097043
# living_area          total_images           0.097043
# balcony              kitchen_area           0.095698
# kitchen_area         balcony                0.095698
# living_total_ratio   studio                 0.094971
# studio               living_total_ratio     0.094971
# total_area           days_exposition        0.093344
# days_exposition      total_area             0.093344
# kitchen_area         living_area            0.091914
# living_area          kitchen_area           0.091914
# airports_nearest     floors_total           0.088191
# floors_total         airports_nearest       0.088191
# balcony              last_price             0.087245
# last_price           balcony                0.087245
# rooms                total_images           0.086665
# total_images         rooms                  0.086665
# parks_around3000     living_total_ratio     0.083580
# living_total_ratio   parks_around3000       0.083580
# kitchen_area         ponds_around3000       0.082454
# ponds_around3000     kitchen_area           0.082454
# parks_nearest        floor                  0.081382
# floor                parks_nearest          0.081382
# total_area           ponds_around3000       0.080931
# ponds_around3000     total_area             0.080931
# living_area          days_exposition        0.079781
# days_exposition      living_area            0.079781
# total_area           balcony                0.078541
# balcony              total_area             0.078541
# last_price           parks_around3000       0.077837
# parks_around3000     last_price             0.077837
# price_per_meter      parks_nearest          0.077829
# parks_nearest        price_per_meter        0.077829
# price_per_meter      parks_around3000       0.075105
# parks_around3000     price_per_meter        0.075105
# studio               floors_total           0.074527
# floors_total         studio                 0.074527
# price_per_meter      year_posted            0.074297
# year_posted          price_per_meter        0.074297
# parks_nearest        kitchen_area           0.070060
# kitchen_area         parks_nearest          0.070060
# living_total_ratio   open_plan              0.068540
# open_plan            living_total_ratio     0.068540
# ceiling_height       apartment              0.068170
# apartment            ceiling_height         0.068170
# days_exposition      rooms                  0.067409
# rooms                days_exposition        0.067409
# last_price           parks_nearest          0.064987
# parks_nearest        last_price             0.064987
# ponds_around3000     parks_nearest          0.061697
# parks_nearest        ponds_around3000       0.061697
# ponds_around3000     price_per_meter        0.061265
# price_per_meter      ponds_around3000       0.061265
# living_area          parks_around3000       0.061073
# parks_around3000     living_area            0.061073
# airports_nearest     floor                  0.059497
# floor                airports_nearest       0.059497
# days_exposition      last_price             0.056665
# last_price           days_exposition        0.056665
# ceiling_height       days_exposition        0.053167
# days_exposition      ceiling_height         0.053167
# floors_total         open_plan              0.052784
# open_plan            floors_total           0.052784
# days_exposition      ponds_around3000       0.051799
# ponds_around3000     days_exposition        0.051799
#                      living_area            0.049680
# living_area          ponds_around3000       0.049680
# price_per_meter      studio                 0.046399
# studio               price_per_meter        0.046399
# balcony              price_per_meter        0.045843
# price_per_meter      balcony                0.045843
# parks_nearest        kitchen_total_ratio    0.045762
# kitchen_total_ratio  parks_nearest          0.045762
# days_exposition      kitchen_area           0.045558
# kitchen_area         days_exposition        0.045558
# total_images         kitchen_area           0.045095
# kitchen_area         total_images           0.045095
# days_exposition      parks_nearest          0.045068
# parks_nearest        days_exposition        0.045068
# total_images         balcony                0.044824
# balcony              total_images           0.044824
# airports_nearest     kitchen_total_ratio    0.040051
# kitchen_total_ratio  airports_nearest       0.040051
# rooms                parks_around3000       0.040031
# parks_around3000     rooms                  0.040031
# parks_nearest        balcony                0.039687
# balcony              parks_nearest          0.039687
# living_area          balcony                0.039357
# balcony              living_area            0.039357
# floor                studio                 0.038294
# studio               floor                  0.038294
#                      ceiling_height         0.038071
# ceiling_height       studio                 0.038071
# year_posted          ponds_nearest          0.038046
# ponds_nearest        year_posted            0.038046
# balcony              airports_nearest       0.037534
# airports_nearest     balcony                0.037534
# open_plan            floor                  0.037108
# floor                open_plan              0.037108
# balcony              open_plan              0.036500
# open_plan            balcony                0.036500
# balcony              cityCenters_nearest    0.034249
# cityCenters_nearest  balcony                0.034249
# apartment            balcony                0.032551
# balcony              apartment              0.032551
# studio               balcony                0.032499
# balcony              studio                 0.032499
# airports_nearest     parks_around3000       0.030608
# parks_around3000     airports_nearest       0.030608
# ponds_nearest        living_total_ratio     0.030517
# living_total_ratio   ponds_nearest          0.030517
# apartment            kitchen_area           0.029900
# kitchen_area         apartment              0.029900
# month_posted         open_plan              0.029437
# open_plan            month_posted           0.029437
# floor                total_images           0.029111
# total_images         floor                  0.029111
# parks_around3000     total_area             0.028397
# total_area           parks_around3000       0.028397
# ceiling_height       balcony                0.027791
# balcony              ceiling_height         0.027791
# parks_around3000     days_exposition        0.027682
# days_exposition      parks_around3000       0.027682
# airports_nearest     kitchen_area           0.026820
# kitchen_area         airports_nearest       0.026820
# balcony              kitchen_total_ratio    0.026562
# kitchen_total_ratio  balcony                0.026562
# parks_nearest        total_area             0.023945
# total_area           parks_nearest          0.023945
# last_price           living_total_ratio     0.023355
# living_total_ratio   last_price             0.023355
# open_plan            price_per_meter        0.022945
# price_per_meter      open_plan              0.022945
# ponds_around3000     cityCenters_nearest    0.021478
# cityCenters_nearest  ponds_around3000       0.021478
# ponds_nearest        apartment              0.020867
# apartment            ponds_nearest          0.020867
#                      cityCenters_nearest    0.020155
# cityCenters_nearest  apartment              0.020155
# ponds_nearest        balcony                0.019983
# balcony              ponds_nearest          0.019983
# month_posted         kitchen_area           0.019869
# kitchen_area         month_posted           0.019869
# apartment            airports_nearest       0.019614
# airports_nearest     apartment              0.019614
# last_price           apartment              0.019572
# apartment            last_price             0.019572
# month_posted         floor                  0.019073
# floor                month_posted           0.019073
# kitchen_total_ratio  apartment              0.019072
# apartment            kitchen_total_ratio    0.019072
# airports_nearest     ponds_nearest          0.018972
# ponds_nearest        airports_nearest       0.018972
# year_posted          cityCenters_nearest    0.018475
# cityCenters_nearest  year_posted            0.018475
# open_plan            ceiling_height         0.018419
# ceiling_height       open_plan              0.018419
# ponds_nearest        parks_nearest          0.016916
# parks_nearest        ponds_nearest          0.016916
# year_posted          apartment              0.016325
# apartment            year_posted            0.016325
# kitchen_total_ratio  month_posted           0.015923
# month_posted         kitchen_total_ratio    0.015923
#                      floors_total           0.014952
# floors_total         month_posted           0.014952
# last_price           year_posted            0.014727
# year_posted          last_price             0.014727
# apartment            total_images           0.014343
# total_images         apartment              0.014343
# floor                ponds_nearest          0.013565
# ponds_nearest        floor                  0.013565
# ponds_around3000     rooms                  0.013519
# rooms                ponds_around3000       0.013519
# total_area           apartment              0.013315
# apartment            total_area             0.013315
# price_per_meter      apartment              0.013164
# apartment            price_per_meter        0.013164
# total_images         living_total_ratio     0.013137
# living_total_ratio   total_images           0.013137
# open_plan            ponds_around3000       0.013007
# ponds_around3000     open_plan              0.013007
# open_plan            parks_nearest          0.012924
# parks_nearest        open_plan              0.012924
# open_plan            weekday_posted         0.012246
# weekday_posted       open_plan              0.012246
# floors_total         weekday_posted         0.011822
# weekday_posted       floors_total           0.011822
#                      floor                  0.011298
# floor                weekday_posted         0.011298
# kitchen_total_ratio  ponds_around3000       0.011212
# ponds_around3000     kitchen_total_ratio    0.011212
# balcony              rooms                  0.011046
# rooms                balcony                0.011046
# month_posted         weekday_posted         0.010880
# weekday_posted       month_posted           0.010880
# studio               year_posted            0.010049
# year_posted          studio                 0.010049
# total_images         floors_total           0.009800
# floors_total         total_images           0.009800
# year_posted          airports_nearest       0.009241
# airports_nearest     year_posted            0.009241
# floors_total         ponds_nearest          0.008816
# ponds_nearest        floors_total           0.008816
# parks_nearest        studio                 0.008763
# studio               parks_nearest          0.008763
# living_total_ratio   weekday_posted         0.008434
# weekday_posted       living_total_ratio     0.008434
# studio               ponds_around3000       0.007128
# ponds_around3000     studio                 0.007128
# year_posted          living_total_ratio     0.006756
# living_total_ratio   year_posted            0.006756
# month_posted         airports_nearest       0.006588
# airports_nearest     month_posted           0.006588
# total_images         month_posted           0.006094
# month_posted         total_images           0.006094
# weekday_posted       cityCenters_nearest    0.004768
# cityCenters_nearest  weekday_posted         0.004768
# month_posted         balcony                0.004299
# balcony              month_posted           0.004299
# total_images         ceiling_height         0.004195
# ceiling_height       total_images           0.004195
# parks_nearest        month_posted           0.004073
# month_posted         parks_nearest          0.004073
# year_posted          kitchen_total_ratio    0.003312
# kitchen_total_ratio  year_posted            0.003312
# living_area          apartment              0.003264
# apartment            living_area            0.003264
# month_posted         total_area             0.003202
# total_area           month_posted           0.003202
# year_posted          balcony                0.002308
# balcony              year_posted            0.002308
# living_total_ratio   days_exposition        0.001240
# days_exposition      living_total_ratio     0.001240
# month_posted         ponds_nearest          0.001225
# ponds_nearest        month_posted           0.001225
# floor                year_posted            0.001159
# year_posted          floor                  0.001159
# parks_around3000     total_images           0.000912
# total_images         parks_around3000       0.000912
# weekday_posted       airports_nearest       0.000560
# airports_nearest     weekday_posted         0.000560
# month_posted         last_price             0.000547
# last_price           month_posted           0.000547
# studio               month_posted           0.000427
# month_posted         studio                 0.000427
# kitchen_total_ratio  weekday_posted         0.000112
# weekday_posted       kitchen_total_ratio    0.000112
# apartment            days_exposition       -0.000110
# days_exposition      apartment             -0.000110
# ponds_nearest        rooms                 -0.000290
# rooms                ponds_nearest         -0.000290
# year_posted          floors_total          -0.000724
# floors_total         year_posted           -0.000724
# ponds_nearest        total_images          -0.000771
# total_images         ponds_nearest         -0.000771
# ponds_around3000     weekday_posted        -0.001107
# weekday_posted       ponds_around3000      -0.001107
# month_posted         parks_around3000      -0.001710
# parks_around3000     month_posted          -0.001710
# living_area          weekday_posted        -0.001738
# weekday_posted       living_area           -0.001738
# apartment            open_plan             -0.002019
# open_plan            apartment             -0.002019
# airports_nearest     total_images          -0.002187
# total_images         airports_nearest      -0.002187
# weekday_posted       studio                -0.002532
# studio               weekday_posted        -0.002532
# ceiling_height       rooms                 -0.002590
# rooms                ceiling_height        -0.002590
# weekday_posted       parks_nearest         -0.002676
# parks_nearest        weekday_posted        -0.002676
# studio               apartment             -0.003015
# apartment            studio                -0.003015
# weekday_posted       rooms                 -0.003635
# rooms                weekday_posted        -0.003635
# weekday_posted       price_per_meter       -0.003954
# price_per_meter      weekday_posted        -0.003954
# total_area           floors_total          -0.004140
# floors_total         total_area            -0.004140
# month_posted         price_per_meter       -0.004545
# price_per_meter      month_posted          -0.004545
# open_plan            studio                -0.004697
# studio               open_plan             -0.004697
# weekday_posted       year_posted           -0.004767
# year_posted          weekday_posted        -0.004767
# weekday_posted       parks_around3000      -0.004771
# parks_around3000     weekday_posted        -0.004771
# ponds_around3000     apartment             -0.005074
# apartment            ponds_around3000      -0.005074
#                      weekday_posted        -0.005368
# weekday_posted       apartment             -0.005368
# open_plan            ponds_nearest         -0.005510
# ponds_nearest        open_plan             -0.005510
# weekday_posted       ceiling_height        -0.005558
# ceiling_height       weekday_posted        -0.005558
# month_posted         ponds_around3000      -0.005587
# ponds_around3000     month_posted          -0.005587
# kitchen_area         rooms                 -0.005828
# rooms                kitchen_area          -0.005828
# weekday_posted       balcony               -0.006074
# balcony              weekday_posted        -0.006074
# ceiling_height       month_posted          -0.006077
# month_posted         ceiling_height        -0.006077
# ponds_nearest        weekday_posted        -0.006176
# weekday_posted       ponds_nearest         -0.006176
# airports_nearest     total_area            -0.006445
# total_area           airports_nearest      -0.006445
# living_area          month_posted          -0.006588
# month_posted         living_area           -0.006588
# weekday_posted       total_images          -0.006637
# total_images         weekday_posted        -0.006637
# rooms                month_posted          -0.006674
# month_posted         rooms                 -0.006674
# weekday_posted       kitchen_area          -0.008160
# kitchen_area         weekday_posted        -0.008160
# cityCenters_nearest  open_plan             -0.008162
# open_plan            cityCenters_nearest   -0.008162
# total_area           weekday_posted        -0.008314
# weekday_posted       total_area            -0.008314
# studio               ponds_nearest         -0.008812
# ponds_nearest        studio                -0.008812
# weekday_posted       last_price            -0.008825
# last_price           weekday_posted        -0.008825
# apartment            floor                 -0.008962
# floor                apartment             -0.008962
# open_plan            parks_around3000      -0.009189
# parks_around3000     open_plan             -0.009189
# rooms                apartment             -0.009559
# apartment            rooms                 -0.009559
# month_posted         apartment             -0.009564
# apartment            month_posted          -0.009564
# living_area          ponds_nearest         -0.009757
# ponds_nearest        living_area           -0.009757
# apartment            living_total_ratio    -0.009824
# living_total_ratio   apartment             -0.009824
# total_images         parks_nearest         -0.010418
# parks_nearest        total_images          -0.010418
# days_exposition      cityCenters_nearest   -0.010590
# cityCenters_nearest  days_exposition       -0.010590
# days_exposition      airports_nearest      -0.011447
# airports_nearest     days_exposition       -0.011447
# living_total_ratio   month_posted          -0.012472
# month_posted         living_total_ratio    -0.012472
# studio               cityCenters_nearest   -0.013183
# cityCenters_nearest  studio                -0.013183
# living_total_ratio   cityCenters_nearest   -0.013247
# cityCenters_nearest  living_total_ratio    -0.013247
# month_posted         cityCenters_nearest   -0.014378
# cityCenters_nearest  month_posted          -0.014378
#                      kitchen_total_ratio   -0.015065
# kitchen_total_ratio  cityCenters_nearest   -0.015065
# airports_nearest     open_plan             -0.015270
# open_plan            airports_nearest      -0.015270
# floors_total         apartment             -0.015287
# apartment            floors_total          -0.015287
# parks_around3000     apartment             -0.016316
# apartment            parks_around3000      -0.016316
# total_area           floor                 -0.016637
# floor                total_area            -0.016637
# last_price           airports_nearest      -0.017189
# airports_nearest     last_price            -0.017189
# weekday_posted       days_exposition       -0.019668
# days_exposition      weekday_posted        -0.019668
#                      balcony               -0.020061
# balcony              days_exposition       -0.020061
# studio               days_exposition       -0.020268
# days_exposition      studio                -0.020268
# ponds_nearest        price_per_meter       -0.020609
# price_per_meter      ponds_nearest         -0.020609
# year_posted          parks_around3000      -0.022007
# parks_around3000     year_posted           -0.022007
# total_images         open_plan             -0.022224
# open_plan            total_images          -0.022224
# parks_nearest        living_area           -0.022497
# living_area          parks_nearest         -0.022497
# year_posted          rooms                 -0.022684
# rooms                year_posted           -0.022684
# studio               airports_nearest      -0.022776
# airports_nearest     studio                -0.022776
# open_plan            year_posted           -0.023009
# year_posted          open_plan             -0.023009
# open_plan            days_exposition       -0.023065
# days_exposition      open_plan             -0.023065
# price_per_meter      days_exposition       -0.023089
# days_exposition      price_per_meter       -0.023089
# living_total_ratio   ponds_around3000      -0.024650
# ponds_around3000     living_total_ratio    -0.024650
#                      total_images          -0.025348
# total_images         ponds_around3000      -0.025348
# days_exposition      kitchen_total_ratio   -0.025768
# kitchen_total_ratio  days_exposition       -0.025768
# parks_nearest        apartment             -0.026613
# apartment            parks_nearest         -0.026613
# total_area           ponds_nearest         -0.026720
# ponds_nearest        total_area            -0.026720
# cityCenters_nearest  ponds_nearest         -0.028581
# ponds_nearest        cityCenters_nearest   -0.028581
# price_per_meter      airports_nearest      -0.029741
# airports_nearest     price_per_meter       -0.029741
# total_images         cityCenters_nearest   -0.030194
# cityCenters_nearest  total_images          -0.030194
# total_images         studio                -0.030205
# studio               total_images          -0.030205
# ponds_around3000     year_posted           -0.031053
# year_posted          ponds_around3000      -0.031053
# parks_around3000     studio                -0.031111
# studio               parks_around3000      -0.031111
# floor                cityCenters_nearest   -0.033067
# cityCenters_nearest  floor                 -0.033067
# kitchen_total_ratio  ponds_nearest         -0.033331
# ponds_nearest        kitchen_total_ratio   -0.033331
# days_exposition      floor                 -0.033935
# floor                days_exposition       -0.033935
# ponds_around3000     balcony               -0.034388
# balcony              ponds_around3000      -0.034388
# year_posted          living_area           -0.034668
# living_area          year_posted           -0.034668
# rooms                parks_nearest         -0.034673
# parks_nearest        rooms                 -0.034673
# days_exposition      floors_total          -0.035014
# floors_total         days_exposition       -0.035014
# parks_nearest        year_posted           -0.035297
# year_posted          parks_nearest         -0.035297
#                      kitchen_area          -0.035431
# kitchen_area         year_posted           -0.035431
# total_images         days_exposition       -0.035445
# days_exposition      total_images          -0.035445
# ceiling_height       parks_nearest         -0.035699
# parks_nearest        ceiling_height        -0.035699
# month_posted         days_exposition       -0.036867
# days_exposition      month_posted          -0.036867
# airports_nearest     rooms                 -0.037467
# rooms                airports_nearest      -0.037467
# living_area          airports_nearest      -0.037530
# airports_nearest     living_area           -0.037530
# ponds_nearest        last_price            -0.038984
# last_price           ponds_nearest         -0.038984
# kitchen_total_ratio  total_images          -0.042814
# total_images         kitchen_total_ratio   -0.042814
# living_area          open_plan             -0.046256
# open_plan            living_area           -0.046256
# year_posted          total_area            -0.046549
# total_area           year_posted           -0.046549
# airports_nearest     ponds_around3000      -0.046865
# ponds_around3000     airports_nearest      -0.046865
#                      floor                 -0.048729
# floor                ponds_around3000      -0.048729
# last_price           open_plan             -0.049114
# open_plan            last_price            -0.049114
# cityCenters_nearest  rooms                 -0.053720
# rooms                cityCenters_nearest   -0.053720
# balcony              living_total_ratio    -0.058270
# living_total_ratio   balcony               -0.058270
# airports_nearest     ceiling_height        -0.061010
# ceiling_height       airports_nearest      -0.061010
# parks_around3000     kitchen_area          -0.061076
# kitchen_area         parks_around3000      -0.061076
#                      ponds_nearest         -0.062180
# ponds_nearest        kitchen_area          -0.062180
# floors_total         cityCenters_nearest   -0.062979
# cityCenters_nearest  floors_total          -0.062979
# parks_nearest        cityCenters_nearest   -0.068102
# cityCenters_nearest  parks_nearest         -0.068102
# balcony              parks_around3000      -0.068578
# parks_around3000     balcony               -0.068578
# parks_nearest        living_total_ratio    -0.074108
# living_total_ratio   parks_nearest         -0.074108
# price_per_meter      total_area            -0.074619
# total_area           price_per_meter       -0.074619
# last_price           studio                -0.075485
# studio               last_price            -0.075485
# year_posted          ceiling_height        -0.076114
# ceiling_height       year_posted           -0.076114
# total_area           open_plan             -0.076187
# open_plan            total_area            -0.076187
# living_total_ratio   airports_nearest      -0.077307
# airports_nearest     living_total_ratio    -0.077307
# studio               living_area           -0.078619
# living_area          studio                -0.078619
# floors_total         ponds_around3000      -0.078986
# ponds_around3000     floors_total          -0.078986
# parks_around3000     kitchen_total_ratio   -0.081924
# kitchen_total_ratio  parks_around3000      -0.081924
# ponds_nearest        days_exposition       -0.082112
# days_exposition      ponds_nearest         -0.082112
# cityCenters_nearest  living_area           -0.084081
# living_area          cityCenters_nearest   -0.084081
# ponds_nearest        ceiling_height        -0.085165
# ceiling_height       ponds_nearest         -0.085165
# parks_around3000     cityCenters_nearest   -0.088550
# cityCenters_nearest  parks_around3000      -0.088550
#                      kitchen_area          -0.088898
# kitchen_area         cityCenters_nearest   -0.088898
# total_area           cityCenters_nearest   -0.094894
# cityCenters_nearest  total_area            -0.094894
# rooms                open_plan             -0.110661
# open_plan            rooms                 -0.110661
# airports_nearest     parks_nearest         -0.115023
# parks_nearest        airports_nearest      -0.115023
# parks_around3000     ponds_nearest         -0.122464
# ponds_nearest        parks_around3000      -0.122464
# studio               total_area            -0.124484
# total_area           studio                -0.124484
# last_price           kitchen_total_ratio   -0.128119
# kitchen_total_ratio  last_price            -0.128119
# floor                living_area           -0.133620
# living_area          floor                 -0.133620
# floor                parks_around3000      -0.147366
# parks_around3000     floor                 -0.147366
# living_area          price_per_meter       -0.169856
# price_per_meter      living_area           -0.169856
# living_area          floors_total          -0.172036
# floors_total         living_area           -0.172036
# rooms                floor                 -0.172919
# floor                rooms                 -0.172919
# studio               rooms                 -0.174568
# rooms                studio                -0.174568
# living_total_ratio   ceiling_height        -0.183559
# ceiling_height       living_total_ratio    -0.183559
# cityCenters_nearest  ceiling_height        -0.216723
# ceiling_height       cityCenters_nearest   -0.216723
# floors_total         parks_around3000      -0.223453
# parks_around3000     floors_total          -0.223453
# rooms                floors_total          -0.230379
# floors_total         rooms                 -0.230379
# rooms                price_per_meter       -0.231217
# price_per_meter      rooms                 -0.231217
# living_total_ratio   price_per_meter       -0.243238
# price_per_meter      living_total_ratio    -0.243238
# parks_around3000     parks_nearest         -0.251942
# parks_nearest        parks_around3000      -0.251942
# year_posted          month_posted          -0.266523
# month_posted         year_posted           -0.266523
# living_total_ratio   floor                 -0.275372
# floor                living_total_ratio    -0.275372
# ponds_nearest        ponds_around3000      -0.296964
# ponds_around3000     ponds_nearest         -0.296964
# cityCenters_nearest  last_price            -0.308743
# last_price           cityCenters_nearest   -0.308743
# living_total_ratio   floors_total          -0.384228
# floors_total         living_total_ratio    -0.384228
# cityCenters_nearest  price_per_meter       -0.397503
# price_per_meter      cityCenters_nearest   -0.397503
# kitchen_total_ratio  total_area            -0.428326
# total_area           kitchen_total_ratio   -0.428326
# living_total_ratio   kitchen_area          -0.483045
# kitchen_area         living_total_ratio    -0.483045
# year_posted          days_exposition       -0.598522
# days_exposition      year_posted           -0.598522
# living_area          kitchen_total_ratio   -0.650873
# kitchen_total_ratio  living_area           -0.650873
#                      rooms                 -0.669078
# rooms                kitchen_total_ratio   -0.669078
# living_total_ratio   kitchen_total_ratio   -0.749472
# kitchen_total_ratio  living_total_ratio    -0.749472
# total_images         total_images                NaN
# last_price           last_price                  NaN
# total_area           total_area                  NaN
# rooms                rooms                       NaN
# ceiling_height       ceiling_height              NaN
# floors_total         floors_total                NaN
# living_area          living_area                 NaN
# floor                floor                       NaN
# apartment            apartment                   NaN
# studio               studio                      NaN
#                      kitchen_area                NaN
#                      kitchen_total_ratio         NaN
# open_plan            open_plan                   NaN
#                      kitchen_area                NaN
#                      kitchen_total_ratio         NaN
# kitchen_area         studio                      NaN
#                      open_plan                   NaN
#                      kitchen_area                NaN
# balcony              balcony                     NaN
# airports_nearest     airports_nearest            NaN
# cityCenters_nearest  cityCenters_nearest         NaN
# parks_around3000     parks_around3000            NaN
# parks_nearest        parks_nearest               NaN
# ponds_around3000     ponds_around3000            NaN
# ponds_nearest        ponds_nearest               NaN
# days_exposition      days_exposition             NaN
# price_per_meter      price_per_meter             NaN
# weekday_posted       weekday_posted              NaN
# month_posted         month_posted                NaN
# year_posted          year_posted                 NaN
# living_total_ratio   living_total_ratio          NaN
# kitchen_total_ratio  studio                      NaN
#                      open_plan                   NaN
#                      kitchen_total_ratio         NaN
# dtype: float64

# %% [markdown]
# Любопытное наблюдение можно сделать по отрицательной части матрицы: чем ближе к концу исследуемого периода, тем быстрее продавались квартиры (`days_exposition` падает по мере увеличения `year_posted` и наоборот, коэффициент Пирсона -0,6).
#
# Значимой корреляции цены квадратного метра с количеством комнат нет. Это может говорить как о том, что эти два параметра никак не связаны, так и о том, что их связь сложнее, чем обычная положительная или отрицательная связь. Сгруппируем даатсет по числу комнат и посмотрим, что происходит с ценой квадратного метра. Для этого создадим функцию, которая пригодится нам для аналогичных операций на следующих шагах. Она принимает на вход номера столбцов из нашего датасета в виде списка и рисует график, на котором видна зависимость медианной цены квадратного метра от соответствующих параметров.

# %%
def price_per_meter_chart(labels):
    for label in labels:
        plt.figure()
        data_filtered.groupby(label)['price_per_meter'].median().plot()
        plt.show()

price_per_meter_chart(['rooms'])

# %% [markdown]
# Цена квадратного метра снижается по мере роста числа комнат в квартире от нуля до пяти, а потом выходит на какое-то странное слишком горизонтальное плато. Посмотрим, сколько в датасете осталось 5- и 6-комнатных квартир, и какая в этих двух категориях медианная цена квадратного метра.

# %%
data_filtered.groupby('rooms')['price_per_meter'].agg(['median', 'count'])
# Out:
#               median  count
# rooms
# 0      104316.770186    186
# 1       99747.122762   7656
# 2       90909.090909   7155
# 3       84585.988799   4530
# 4       80041.067762    540
# 5       72222.222222     27
# 6       72252.631579      1

# %% [markdown]
# Оказывается, в датасете осталась всего одна 6-комнатная квартира, и цена ее действительно близка к медианной по 5-комнатным. Изучать единственную 6-комнатную квартиру бесполезно, придется ее удалить.

# %%
data_filtered = data_filtered.query('rooms != 6')

# %% [markdown]
# Теперь выясним, влияет ли размещение квартиры на первом или последнем этаже на цену квадратного метра в ней.

# %%
data_filtered.groupby('floor_type')['price_per_meter'].median()
# Out:
# floor_type
# другой       95590.187748
# первый       80163.043478
# последний    84126.984127
# Name: price_per_meter, dtype: float64

# %% [markdown]
# Тут без сюрпризов: на первых этажах метры самые дешевые, на последнем чуть подороже, а на остальных этажах цена чуть выше среднего.
#
# Есть ли связь между удаленностью от центра и ценой квадратного метра?

# %%
data_filtered.plot(x='cityCenters_nearest', y='price_per_meter', kind='scatter', alpha=0.03)

# %% [markdown]
# В центрах городов (еле заметная вертикальная полоса, расположенная на графике в районе отметки 4 км) есть и совсем дорогие квартиры, и варианты подешевле, а нижняя ценовая граница бошинства предложений -- около 80 тыс. рублей за метр. В зоне, которая соответствует спальным районам и пригородам Санкт-Петербурга, а также дальним окрестностям более мелких городов (темное пятно на удалении 10-20 км от центров), спектр предложений по мере удаления от центров становится шире: ставка за квадратный метр начинается примерно от 60 тыс, но и дорогих предложений почти столько же, сколько ближе к центру. По мере дальнейшего удаления от условного центра диапазон цен сужается при сохранении нижней границы на уровне в 50-60 тыс. рублей.
#
# Изучим, как на цене квадратного метра отражается день недели, месяц и год, когда было вывешено объявление.

# %%
price_per_meter_chart(['weekday_posted', 'month_posted', 'year_posted'])

# %% [markdown]
# Выгоднее всего выставлять квартиру на продажу во вторник. В субботу лучше этого не делать. Самые неудачные месяцы для продажи квартиры -- июнь и декабрь, самые удачные -- апрель и август. На последнем графике видим другое проявление той же динамики, которую заметили в матрице корреляций. Там с течением времени падал срок экспозиции квартир, а здесь начиная с 2018 года резко растет цена квадратного метра (до этого два года наблюдалась стангнация, а еще годом раньше цены на рынке недвижимости упали). Спрос на квартиры вырос.

# %% [markdown]
# ### <font color='red'>Комментарий от наставника 5 <span style="color:green;font-size:200%">&#10003;</span>
# Мне очень нравится твой анализ и выводы, молодец! Единственное, я предлагаю тут тоже немного "автоматизировать" построение однотипных графиков с помощью цикла по выбранным столбцам. Ты можешь в цикле построить графики. В такой клетке будет большой вывод, но это не страшно, его всегда можно спрятать. А дальше я предлагаю последовательно пробежаться глазами по этим графикам и в следующей клетке написать один хороший комментарий по тому, что ты там увидел.
#
# -----

# %% [markdown]
# <font color='orange'> Сделал.

# %% [markdown]
# ### <font color='blue'>Комментарий от наставника 4 итерация 2 <span style="color:green;font-size:200%">&#10003;</span>
# Тут всё хорошо, только я бы советовала оперировать не с индексами колонок, а с их названиями (вдруг завтра к нам придёт новый датасет, в котором будет больше колонок и индексы поедут).<br>
# Ну то есть никто ведь не мешает передавать список строк и по нему потом в цикле пробегаться.

# %% [markdown]
# Посмотрим, какие населенные пункты лидируют по количеству объявленний.

# %%
data.groupby('locality_name')['last_price'].count().sort_values(ascending=False).head(10)
# Out:
# locality_name
# санкт-петербург      15720
# посёлок мурино         522
# посёлок шушары         440
# всеволожск             398
# пушкин                 369
# колпино                338
# посёлок парголово      327
# гатчина                307
# деревня кудрово        299
# выборг                 237
# Name: last_price, dtype: int64

# %% [markdown]
# Поселок Мурино, второй по числу объявлений после Санкт-Петербурга, в апреле этого года получил статус города. То же самое, только годом раньше, случилось с деревней Кудрово, номер 9 в списке. Всеволожск и Выбобрг (4 и 10) -- тоже города, а все остальные населенные пункты из первой десятки административно входят в Санкт-Петербург. Причем Кудрово лежит в пределах Кольцевой автодороги, Мурино вплотную к ней примыкает, а Всеволожск удален от Санкт-Петербурга меньше, чем на 10 километров. То есть на самом деле все, кроме Выборга, это либо Санкт-Петербург, либо его пригороды. Посмотрим, как местоположение влияет на цену квадратного метра (статус Мурино и Кудрово менять не будем, потому что большую часть исследуемого периода они городами не были.)

# %%
# превращаем предыдущую группировку в список населенных пунктов, фильтруем по нему датасет и смотрим медицану цены метра
top10 = list(data.groupby('locality_name')['last_price'].count().sort_values(ascending=False).head(10).index)
data_filtered.query('locality_name in @top10').groupby('locality_name')['price_per_meter'].median()\
.sort_values(ascending=False)
# Out:
# locality_name
# санкт-петербург      101630.650403
# пушкин                98437.500000
# посёлок парголово     91917.591125
# деревня кудрово       91803.278689
# посёлок мурино        85878.462169
# посёлок шушары        76923.076923
# колпино               74723.748474
# гатчина               67924.528302
# всеволожск            65789.473684
# выборг                58108.108108
# Name: price_per_meter, dtype: float64

# %% [markdown]
# Опять обошлось без сюрпризов: даже административное деление в пределах Санкт-Петербурга влияет на цену квадратного метра. В наиболее удаленных от центра Санкт-Петербурга Всеволожске и Выборге и квадратный метр дешевле.
#
# Интересно, насколько велика будет разница, если всю недвижимость в датасете поделить на городскую и сельскую? Сначала посмотрим, какие значения в принципе есть `locality_name`.

# %%
data_filtered.locality_name.unique()
# Out:
# array(['посёлок шушары', 'санкт-петербург', 'городской посёлок янино-1',
#        'посёлок парголово', 'посёлок мурино', 'ломоносов', 'сертолово',
#        'петергоф', 'пушкин', 'деревня кудрово', 'коммунар', 'колпино',
#        'поселок городского типа красный бор', 'гатчина', 'поселок мурино',
#        'деревня фёдоровское', 'выборг', 'кронштадт', 'кировск',
#        'деревня новое девяткино', 'посёлок металлострой',
#        'посёлок городского типа лебяжье',
#        'посёлок городского типа сиверский', 'поселок молодцово',
#        'поселок городского типа кузьмоловский',
#        'садовое товарищество новая ропша', 'павловск',
#        'деревня пикколово', 'всеволожск', 'волхов', 'кингисепп',
#        'приозерск', 'деревня куттузи', 'сестрорецк', 'посёлок аннино',
#        'посёлок плодовое', 'деревня заклинье', 'поселок первомайское',
#        'красное село', 'посёлок понтонный', 'сясьстрой', 'деревня старая',
#        'деревня лесколово', 'посёлок новый свет', 'село путилово',
#        'ивангород', 'мурино', 'шлиссельбург', 'никольское', 'зеленогорск',
#        'поселок новый свет', 'деревня оржицы', 'деревня кальтино',
#        'кудрово', 'поселок романовка', 'посёлок бугры', 'поселок бугры',
#        'сланцы', 'поселок городского типа рощино', 'сосновый бор',
#        'кириши', 'луга', 'волосово', 'отрадное', 'село павлово',
#        'село копорье', 'посёлок городского типа красный бор',
#        'посёлок молодёжное', 'тихвин', 'посёлок победа', 'деревня нурма',
#        'посёлок городского типа кузьмоловский', 'посёлок стрельна',
#        'деревня лопухинка', 'поселок терволово',
#        'поселок городского типа советский', 'подпорожье',
#        'посёлок петровское', 'посёлок городского типа токсово',
#        'поселок сельцо', 'тосно', 'посёлок городского типа вырица',
#        'деревня кипень', 'деревня келози', 'деревня вартемяги',
#        'посёлок тельмана', 'поселок севастьяново',
#        'городской поселок большая ижора', 'городской посёлок павлово',
#        'деревня агалатово', 'посёлок новогорелово', 'деревня лаголово',
#        'поселок цвелодубово', 'поселок городского типа рахья',
#        'поселок городского типа вырица', 'деревня белогорка',
#        'поселок заводской', 'городской посёлок новоселье',
#        'деревня большие колпаны', 'деревня горбунки', 'деревня батово',
#        'деревня заневка', 'деревня иссад', 'приморск',
#        'городской посёлок фёдоровское', 'деревня мистолово',
#        'новая ладога', 'поселок зимитицы', 'поселок барышево',
#        'деревня разметелево', 'поселок городского типа имени свердлова',
#        'деревня пеники', 'поселок рябово', 'деревня пудомяги',
#        'поселок станции корнево', 'деревня низино', 'деревня бегуницы',
#        'посёлок поляны', 'городской посёлок мга', 'поселок елизаветино',
#        'посёлок городского типа кузнечное',
#        'поселок городского типа синявино', 'деревня колтуши',
#        'поселок запорожское', 'посёлок городского типа рощино',
#        'деревня гостилицы', 'деревня малое карлино',
#        'посёлок мичуринское', 'посёлок песочный', 'посёлок сосново',
#        'деревня аро', 'поселок ильичёво', 'посёлок городского типа тайцы',
#        'деревня малое верево', 'деревня извара', 'поселок станции вещево',
#        'село паша', 'деревня калитино', 'неизвестно',
#        'посёлок городского типа ульяновка',
#        'поселок городского типа дубровка', 'деревня мины',
#        'поселок войсковицы', 'посёлок городского типа имени свердлова',
#        'деревня коркино', 'поселок городского типа приладожский',
#        'посёлок щеглово', 'посёлок гаврилово', 'лодейное поле',
#        'пикалёво', 'деревня рабитицы', 'деревня кузьмолово',
#        'деревня малые колпаны', 'поселок тельмана',
#        'посёлок петро-славянка', 'городской посёлок назия',
#        'посёлок ильичёво', 'поселок углово', 'поселок старая малукса',
#        'садовое товарищество рахья', 'поселок аннино', 'поселок победа',
#        'деревня меньково', 'деревня старые бегуницы',
#        'посёлок городского типа имени морозова', 'посёлок сапёрный',
#        'поселок семрино', 'поселок гаврилово', 'поселок глажево',
#        'поселок кобринское', 'деревня гарболово', 'деревня юкки',
#        'поселок станции приветнинское', 'деревня мануйлово',
#        'деревня пчева', 'поселок поляны', 'поселок мельниково',
#        'посёлок пудость', 'посёлок усть-луга', 'светогорск', 'любань',
#        'поселок селезнёво', 'поселок городского типа рябово',
#        'каменногорск', 'деревня кривко', 'поселок глебычево',
#        'деревня парицы', 'поселок жилпосёлок',
#        'посёлок городского типа мга', 'городской поселок янино-1',
#        'посёлок войскорово', 'село никольское', 'посёлок терволово',
#        'поселок стеклянный', 'посёлок мыза-ивановка',
#        'село русско-высоцкое', 'поселок городского типа лебяжье',
#        'поселок городского типа форносово', 'село старая ладога',
#        'городской посёлок виллози', 'деревня лампово',
#        'деревня шпаньково', 'деревня лаврики', 'посёлок возрождение',
#        'деревня старосиверская', 'посёлок кикерино',
#        'поселок возрождение', 'деревня старое хинколово',
#        'посёлок пригородный', 'посёлок торфяное', 'поселок суходолье',
#        'поселок красная долина', 'деревня хапо-ое',
#        'поселок городского типа дружная горка', 'поселок лисий нос',
#        'деревня яльгелево', 'посёлок стеклянный', 'село рождествено',
#        'посёлок левашово', 'деревня сяськелево', 'деревня камышовка',
#        'садоводческое некоммерческое товарищество лесная поляна',
#        'поселок жилгородок', 'посёлок городского типа павлово',
#        'поселок новый учхоз', 'городской посёлок рощино',
#        'поселок гончарово', 'посёлок сапёрное',
#        'посёлок платформа 69-й километр', 'поселок каложицы',
#        'посёлок белоостров', 'поселок лукаши', 'поселок петровское',
#        'деревня щеглово', 'поселок мичуринское', 'деревня тарасово',
#        'поселок кингисеппский',
#        'посёлок при железнодорожной станции вещево', 'поселок ушаки',
#        'деревня котлы', 'деревня торосово', 'посёлок форт красная горка',
#        'деревня новолисино', 'посёлок станции громово', 'деревня глинка',
#        'посёлок мельниково', 'поселок городского типа назия',
#        'деревня старая пустошь', 'поселок коммунары', 'поселок починок',
#        'посёлок городского типа вознесенье', 'посёлок репино',
#        'деревня разбегаево', 'посёлок городского типа рябово',
#        'поселок гладкое',
#        'посёлок при железнодорожной станции приветнинское',
#        'посёлок жилгородок', 'посёлок коробицыно',
#        'деревня большая вруда', 'городской посёлок лесогорский',
#        'деревня курковицы', 'посёлок лисий нос',
#        'городской посёлок советский', 'посёлок кобралово',
#        'деревня суоранда', 'поселок кобралово',
#        'поселок городского типа кондратьево',
#        'коттеджный поселок счастье', 'поселок любань', 'деревня реброво',
#        'городской посёлок будогощь', 'деревня зимитицы',
#        'деревня тойворово', 'поселок семиозерье', 'поселок лесное',
#        'поселок усть-луга', 'посёлок ленинское', 'посёлок суйда',
#        'посёлок городского типа форносово', 'поселок торковичи',
#        'деревня нижние осельки', 'поселок перово', 'высоцк',
#        'поселок гарболово', 'село шум', 'поселок котельский',
#        'посёлок городского типа важины', 'деревня большая пустомержа',
#        'поселок красносельское', 'деревня пижма',
#        'коттеджный поселок кивеннапа север', 'поселок коробицыно',
#        'поселок ромашки', 'посёлок перово', 'деревня каськово',
#        'деревня куровицы', 'поселок сумино',
#        'поселок городского типа большая ижора', 'поселок кирпичное',
#        'деревня раздолье', 'деревня терпилицы',
#        'поселок городского типа токсово', 'деревня ваганово',
#        'поселок пушное', 'садовое товарищество садко',
#        'посёлок усть-ижора', 'поселок городского типа лесогорский',
#        'городской посёлок свирьстрой', 'поселок громово',
#        'посёлок старая малукса', 'деревня трубников бор',
#        'поселок калитино', 'посёлок высокоключевой',
#        'садовое товарищество приладожский',
#        'посёлок пансионат зелёный бор', 'деревня ненимяки',
#        'поселок пансионат зелёный бор', 'деревня снегирёвка',
#        'посёлок александровская', 'деревня рапполово', 'деревня пустынка',
#        'поселок рабитицы', 'деревня русско', 'деревня лупполово',
#        'деревня большое рейзино', 'поселок дружноселье',
#        'коттеджный посёлок лесное', 'деревня борисова грива',
#        'посёлок дзержинского'], dtype=object)

# %% [markdown]
# Во многих случаях тип населенного пункта указан вместе с названием. Попробуем отфильтровать датасет по этому принципу.

# %%
data_filtered[~data_filtered['locality_name'].str.contains(
    'поселок|посёлок|деревня|село|садовое товарищество|садоводческое некоммерческое товарищество'
)]['locality_name'].unique()
# Out:
# array(['санкт-петербург', 'ломоносов', 'сертолово', 'петергоф', 'пушкин',
#        'коммунар', 'колпино', 'гатчина', 'выборг', 'кронштадт', 'кировск',
#        'павловск', 'всеволожск', 'волхов', 'кингисепп', 'приозерск',
#        'сестрорецк', 'сясьстрой', 'ивангород', 'мурино', 'шлиссельбург',
#        'никольское', 'зеленогорск', 'кудрово', 'сланцы', 'сосновый бор',
#        'кириши', 'луга', 'волосово', 'отрадное', 'тихвин', 'подпорожье',
#        'тосно', 'приморск', 'новая ладога', 'неизвестно', 'лодейное поле',
#        'пикалёво', 'светогорск', 'любань', 'каменногорск', 'высоцк'],
#       dtype=object)

# %% [markdown]
# Отлично. Видимо, данные о населенном пункте вносились автоматически, раз без всякой лемматизации получился такой чистый список. Он достаточно короткий, чтобы пробежать его глазами и убедиться, что все остальные населенные пункты в столбце `locality_name` -- это города (или части городов, как Петергоф). Теперь создадим новый столбец, в котором отделим города от сельских населенных пунктов и немногочисленных пропусков. Затем посмотрим, как отличается цена квадратного метра.

# %%
def define_locality_type(string):
    if 'поселок' in string or 'посёлок' in string or 'деревня' in string or 'село' in string or \
    'садовое товарищество' in string or 'садоводческое некоммерческое товарищество' in string:
        return 'село'
    if 'неизвестно' in string:
        return 'неизвестно'
    else:
        return 'город'

data_filtered['locality_type'] = data_filtered.locality_name.apply(define_locality_type)

data_filtered.query('locality_type == "город" or locality_type == "село"')\
.groupby('locality_type')['price_per_meter'].median()
# Out:
# locality_type
# город    96457.317706
# село     71875.000000
# Name: price_per_meter, dtype: float64

# %% [markdown]
# Выходит, в Гатчине, Всеволожске и особенно Выборге цена метра недвижимости ниже сельской. Наверняка в значительной степени из-за таких "деревень", как Мурино и Кудрово. Кстати, на их примере удобно исследовать влияние статуса города на цену квадратного метра (сравнить цены на недвижимость до и после изменения статуса с поправкой на динамику рынка в целом).
#
# Теперь сравним квартиры "в центре" и не в центре. Санкт-Петербург и так домиинирует в датасете, но все же отберем только строки с "санкт-петерубргом" в `locality_name`. За условную границу центра примем окружность радиусом не менее 4 км: с одной стороны, это чуть больше расстояния от Адмиралтейства до Московского вокзала или Обводного канала, с другой стороны -- как раз включает в себя ядро первой зоны, которую мы видели на диаграмме рассеивания выше. Еще один критерий -- в выборке должно оказаться не менее 1000 строк. Внешнюю границу исследуемой области проведем в 15 км от центра: сюда попадет территория в границах Кольцевой автодороги и часть пригородов.

# %%
downtown = data_filtered.query('cityCenters_nearest <= 5130 and locality_name == "санкт-петербург"')
len(downtown)
# Out:
# 837

# %%
suburbs = data_filtered.query('5130 < cityCenters_nearest <= 15000 and locality_name == "санкт-петербург"')
len(suburbs)
# Out:
# 8094

# %% [markdown]
# Cоставим таблицу, в которой данные будут представлены для обеих выборок с разбивкой по числу комнат.

# %%
# выделим интересующие нас столбцы
columns_of_interest = ['price_per_meter', 'total_area', 'cityCenters_nearest']

# посчитаем средние
downtown_grouped = downtown.groupby('rooms')[columns_of_interest].mean()
suburbs_grouped = suburbs.groupby('rooms')[columns_of_interest].mean()

# объединим таблицы
downtown_vs_suburbs = downtown_grouped.join(suburbs_grouped, lsuffix='_dt', rsuffix='_su')

# добавим информацию о количестве квартир с разным количеством комнат
downtown_vs_suburbs['count_dt'] = downtown.groupby('rooms')['last_price'].count()
downtown_vs_suburbs['count_su'] = suburbs.groupby('rooms')['last_price'].count()

# для наглядности изменим порядок столбцов
downtown_vs_suburbs[['price_per_meter_dt', 'price_per_meter_su', 'total_area_dt', 'total_area_su', 
                     'cityCenters_nearest_dt', 'cityCenters_nearest_su', 'count_dt', 'count_su']]
# Out:
#        price_per_meter_dt  price_per_meter_su  total_area_dt  total_area_su  \
# rooms
# 0           129879.108030       123541.416904      19.525000      28.320312
# 1           130577.334441       113962.388745      41.408912      37.605261
# 2           115759.214522       105545.284686      61.016738      54.567063
# 3           107031.265851        95576.441415      75.776548      69.711051
# 4            95565.955457        86454.023448      87.359722      73.161899
# 5           112751.056550        75545.497506      87.720000      75.700000
#
#        cityCenters_nearest_dt  cityCenters_nearest_su  count_dt  count_su
# rooms
# 0                 3177.000000            11838.531250         4        64
# 1                 4060.843537            11833.003025       147      2975
# 2                 3591.134146            11414.980892       328      2983
# 3                 3528.690391            11453.002189       281      1827
# 4                 3495.291667            11410.649789        72       237
# 5                 3161.200000            12313.125000         5         8

# %% [markdown]
# Делать вывыды о студиях/квартирах открытой планировки и о квартирах с числом комнат больше 4 мы не можем, слишком мало информации.
#
# Разница в цене метра между центром и окраинами сильнее всего проявляется на однокомнатных квартирах, а слабее всего -- на четырехкомнатных. На 2-3-комнатных она примерно одинакова. Квартиры в центре просторнее, независимо от количества комнат. В обеих зонах чем ближе к центру, тем больше в среднем в квартире комнат, но двушки и трешки располагаются примерно на одинаковом удалении (3,61 и 11,35 км от центра соответственно) -- и это единственный сегмент, который можно выделить в обеих выборках.

# %%
downtown_vs_suburbs.boxplot(['price_per_meter_dt', 'price_per_meter_su'])

# %% [markdown]
# Ценовая вилка в пригорордах шире, чем в центре, и цены в целом несколько ниже.

# %%
downtown_vs_suburbs.boxplot(['total_area_dt', 'total_area_su'])

# %% [markdown]
# Квартиры-студии и многокомнатные квартиры, которые мы не учитывали в разбивке по числу комнат, здесь заметно расширяют диапазон значений для центральной выборки.
#
# Сравним корреляцию основных факторов в трех выборках: общей, центральной и пригородной.

# %%
compare_corrs = data_filtered.corr().loc['last_price'].reset_index().set_index('index').merge(
    downtown.corr().loc['last_price'].reset_index().set_index('index'), left_index=True, right_index=True).merge(
    suburbs.corr().loc['last_price'].reset_index().set_index('index'), left_index=True, right_index=True)

compare_corrs.columns = ['last_price_all', 'last_price_dt', 'last_price_su']

compare_corrs.sort_values('last_price_all', ascending=False).head(10)
# Out:
#                  last_price_all  last_price_dt  last_price_su
# index
# last_price             1.000000       1.000000       1.000000
# total_area             0.708007       0.739269       0.826382
# price_per_meter        0.620351       0.280717       0.398003
# living_area            0.572402       0.603210       0.655490
# kitchen_area           0.463527       0.339901       0.540244
# rooms                  0.441099       0.484781       0.483008
# ceiling_height         0.407687       0.131728       0.424311
# floors_total           0.234475       0.138311       0.221556
# total_images           0.164027       0.080886       0.153852
# floor                  0.157716       0.190495       0.145470

# %% [markdown]
# В центре общая площадь квартиры коррелирует с ее ценой примерно так же, как и в общей выборке, а в пригороде коэффициент корреляции заметно выше (0,74, 0,71 и 0,83). Другими словами, в спальных районах главное достоинство квартиры -- ее общая площадь.
#
# Из следующих строк видно, что эта разница обеспечивается во многом вниманием к площади кухни и лишь в малой степени -- к площади жилых помещений и количеству комнат: в центре корреляция `kitchen_area` с итоговой ценой на 0,12 слабее, чем в общей выборке, а в пригородах -- на 0,08 сильнее. Разница между центром и пригородом очень заметная: 0,21.
#
# Еще можно сделать вывод, что продавцы и покупатели квартир в центре значительно меньше внимания уделяют высоте потолков: коэффициент Пирсона отличается на целых 0,29 (0,42 в общей и пригородной выборках против 0,13 в центральной).
#
# Перейдем к изучению апартаментов, студий и квартир свободной планировки. Сравним их с остальными квартирами по средним значениям цены за квадратный метр, площади, срокам экспозиции и удаленности от центра. Для этого сначала создадим вспомогательный столбец с маркерами.

# %%
data_filtered.loc[
    (data_filtered['apartment'] == True) | 
    (data_filtered['studio'] == True) | 
    (data_filtered['open_plan'] == True), 
    'typical_or_not'] = 'untypical'

data_filtered.loc[
    (data_filtered['apartment'] != True) & 
    (data_filtered['studio'] != True) & 
    (data_filtered['open_plan'] != True), 
    'typical_or_not'] = 'typical'

len(data_filtered.query('typical_or_not == "untypical"'))
# Out:
# 229

# %% [markdown]
# Выборка нетипичных квартир получилась совсем маленькая, но делать нечего.

# %%
data_filtered.boxplot(column='price_per_meter', by='typical_or_not')

# %% [markdown]
# Ставка за квадратный метр в нетипичных квартирах начинается с 50 тыс. рублей, что почти в два раза дороже, чем у самых дешевых из обычных квартир. Дорогие квариры в обеих категориях стоят одинаково.

# %%
data_filtered.boxplot(column='total_area', by='typical_or_not')

# %% [markdown]
# Площадь нетипичных квартир не превышаает 40 кв. м. Обычные квартиры часто бывают в 2,5 раза больше.

# %%
data_filtered.boxplot(column='days_exposition', by='typical_or_not')

# %% [markdown]
# Нетипичные квартиры обычно продаются значительно быстрее типичных. На целых 150 дней.

# %%
data_filtered.boxplot(column='cityCenters_nearest', by='typical_or_not')

# %% [markdown]
# По удаленности от центра значимых различий не видно.
#
# Посмотрим, отличаются ли корреляции между этими параметрами и общей ценой квартир в двух категориях.

# %%
typical_corr = data_filtered.query('typical_or_not == "typical"').corr().loc['last_price'].reset_index()\
.set_index('index')

untypical_corr = data_filtered.query('typical_or_not == "untypical"').corr().loc['last_price'].reset_index()\
.set_index('index')

compare_corrs_2 = typical_corr.merge(untypical_corr, left_index=True, right_index=True, suffixes=('_typ', '_untyp'))
compare_corrs_2.sort_values('last_price_typ', ascending=False).head(10)
# Out:
#                  last_price_typ  last_price_untyp
# index
# last_price             1.000000          1.000000
# total_area             0.705212          0.825632
# price_per_meter        0.629028          0.418379
# living_area            0.568585          0.736552
# kitchen_area           0.463910          0.323328
# rooms                  0.434408          0.601935
# ceiling_height         0.412826          0.424008
# floors_total           0.246930         -0.243002
# floor                  0.164634         -0.062304
# total_images           0.161754          0.224376

# %% [markdown]
# В квартирах нетиповой планировки цена коррелирует с площадью сильнее, чем в обычных. Разница в строке `kitchen_area` объясняется тем, что в квартирах нетиповой планировки кухня совмещена с жилой площадью и отдельно не учитывается. Каждая лишняя комната сказывается на цене нетиповых квартир сильнее, чем типовых.

# %% [markdown]
# ### Выводы. <span style="color:green;font-size:200%">&#10003;</span>

# %% [markdown]
# Мы исследовали рынок жилой недвижимости Санкт-Петербурга за последние пять лет и выявили основные параметры продаваемых квартир:
#
# * количество комнат до 5, в среднем чуть меньше 2
# * общая площадь от 13 до 115 кв. м, в среднем 53 кв. м
# * цена за квадратный метр от 22 до 162 тыс. рублей, среднее и медианное значения -- 92 и 93 тыс.
# * стоимость за всю квартиру от 0,65 до 17,9 млн рублей
# * в норме квартира проводит на рынке не более 480 дней, а половина всех квартир продается быстрее, чем за 100 дней
#
# Также удалось определить основные параметры, положительно коррелирующие со стоимостью квартиры (помимо ее размера):
#
# * жилая площадь (с большим отрывом опережает следующие)
# * площадь кухни
# * количество комнат
#
# Шестикомнатные квартиры (объекты с большим числом комнат не изучались) выделяются значительно более высокой ценой квадратного метра.
#
# Получил подтверждение известный факт, что квартиры, расположенные не на первом и не на последнем этаже здания ценятся выше.
#
# О распределении цен по географическому признаку можно сказать следующее. В центрах городов есть и совсем дорогие квартиры, и варианты подешевле. Нижняя ценовая граница бошинства предложений -- около 80 тыс. рублей за метр. В зоне, которая соответствует спальным районам и пригородам Санкт-Петербурга, а также дальним окрестностям более мелких городов, спектр предложений по мере удаления от центров становится шире: минимальная ставка за квадратный метр опускается примерно до 60 тыс., но и дорогих предложений почти столько же, сколько ближе к центру. По мере дальнейшего удаления диапазон цен сужается при сохранении нижней границы на уровне в 50-60 тыс. рублей.
#
# Годовой цикл рынка недвижимости характеризуется пиками активности в апреле и августе и спадами в июне и декабре. Оказалось, что существует и недельный цикл: в объявлениях, опубликованных во вторник, медианная цена квадратного метра выше, чем в опубликованных в субботу.
#
# В течение пяти лет, которые охватывает это исследование, рынок недвижимости Ленинградской области пережил сначала спад, затем два года стагнации и, наконец, резкий рост начиная с 2018 года. Это видно как по росту цены квадратного метра, так и по снижению срока экспозиции квартир.
#
# Медианная цена квадратного метра в зависимости от расположения квартиры варьируется от 102 тыс. в Санкт-Петербурге до 65 тыс. в его дальних пригородах и от 97 тыс. в городах Ленинградской области до 72 тыс. в сельских населенных пунктах.
#
# Если рассмотреть Санкт-Петербург отдельно от всех остальных населенных пунктов, то разница в средней цене метра между его центром и окраинами сильнее всего проявляется на однокомнатных квартирах (17 тыс. рублей), а слабее всего -- на четырехкомнатных (7 тыс. рублей). На 2-3-комнатных она примерно одинакова (11 тыс. рублей).
#
# Квартиры в центре просторнее, независимо от количества комнат. В обеих зонах чем ближе к центру, тем больше в среднем в квартире комнат, но двушки и трешки располагаются примерно на одинаковом удалении (3,61 и 11,35 км от центра соответственно). Двух- и трехкомнатные квартиры имеют схожие характеристики, поэтому их можно выделить в единый сегмент.
#
# Ценовая вилка в пригорордах Санкт-Петербурга шире, чем в центре, и цены в целом несколько ниже.
#
# В центре общая площадь квартиры коррелирует с ее ценой примерно так же, как и в общей выборке, а в пригороде коэффициент корреляции заметно выше (0,74, 0,71 и 0,83). Другими словами, в спальных районах главное достоинство квартиры -- ее общая площадь.
#
# Из следующих строк видно, что эта разница обеспечивается во многом вниманием к площади кухни и лишь в малой степени -- к площади жилых помещений и количеству комнат: в центре корреляция площади кухни с итоговой ценой на 0,12 слабее, чем в общей выборке, а в пригородах -- на 0,08 сильнее. Разница между центром и пригородом очень заметная: 0,21.
#
# Еще можно сделать вывод, что продавцы и покупатели квартир в центре значительно меньше внимания уделяют высоте потолков: коэффициент Пирсона отличается на целых 0,29 (0,42 в общей и пригородной выборках против 0,13 в центральной).
#
# Наконец, мы специально остановились на особенностях апартаментов, студий и квартир свободной планировки. Ставка за квадратный метр в таких квартирах начинается с 50 тыс. рублей, что почти в два раза дороже, чем у самых дешевых из обычных квартир. Дорогие квариры в обеих категориях стоят одинаково. Площадь апартаментов, студий и квартир свободной планировки очень редко превышаает 40 кв. м (обычные квартиры часто бывают в 2,5 раза больше), а продаются они обычно на целых 150 дней быстрее остальных. Каждая лишняя комната сказывается на цене нетиповых квартир сильнее, чем в случае обычных квартир.
#
# Техническому специалисту, ответственному за выгрузку, сообщим, что в полученном датасете было два столбца с одинаковыми значениями (`area` и `total_area`).

# %% [markdown]
# ### <font color='red'>Комментарий от наставника по всей работе <span style="color:green;font-size:200%">&#10003;</span>
# Мне нравится твоя работа, у тебя получилось очень качественное исследование, молодец! Особенно хороши выводы - очень развёрнуто, при этом всё по делу.
#
# Единственное, давай добавим "автоматизации" к нашему исследованию. Смотри комментарии 4 и 5.<br>
# И ещё не помешало бы в процессе исследования всё-таки немного разграничивать наши шаги с помощью заголовков в markdown ячейках.
#
# Уверена, для тебя не составит труда это исправить :)
#
# ### <font color='blue'>Комментарий от наставника по всей работе итерация 2 <span style="color:green;font-size:200%">&#10003;</span>
# Ты постарался всё исправить и у тебя отлично вышло, молодец! Давай поправим пару новых комментариев и я приму работу :)
#
# ### <font color='green'> Финальный комментарий от наставника
# Спасибо за исправления, работа принята!
