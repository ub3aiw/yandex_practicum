# %% [markdown]
# ## Задание 1. Что такое проекты в Jupyter

# %% [markdown]
# Проекты в Jupyter оформляются в виде так называемых **тетрадок *Jupyter Notebook***. Тетрадка — это смесь текста и кода на Python. Пример такой тетрадки вы сейчас читаете.
#
# Пора приступать к выполнению кода. Перейдите в ячейку под этим текстом и нажмите **Shift+Enter**, либо кликните по кнопке **( ▶| Run )** сверху.

# %%
print("Я - аналитик данных! 😎")
a = 2
b = 3
sum = a + b
print("Я умею складывать числа, a + b =", sum)
# Out:
# Я - аналитик данных! 😎
# Я умею складывать числа, a + b = 5

# %% [markdown]
# Ячейки могут содержать любой код на языке Python. Всё практически как в уже знакомом вам тренажёре.

# %% [markdown]
# ## Задание 2. Как исполняется код в ячейках Jupyter Notebook

# %% [markdown]
# Результат выполнения кода отображается прямо под ним. Не нужно писать вызов `print()` — значение последнего вычисленного выражения отобразится и так. Убедитесь в этом, исполнив следующий код:

# %%
def SumSquare(x, y):
  return x*x + y*y;

a = 2
b = 3

SumSquare(a, b)
# Out:
# 13

# %% [markdown]
# Получилось 13. Это потому, что значения переменных a и b сохранились после выполнения кода предыдущих ячеек.
#
# Код в каждой ячейке — часть общей программы. Так как вы управляете запуском ячеек вручную, можете выполнять их в любом порядке, даже редактируя и перезапуская. Таким образом  вы влияете на значения переменных, которые сохраняются от ячейки к ячейке.
#
# Рекомендуем запускать код по порядку, чтобы результат выполнения был предсказуем. Если выбрать в меню **( Cell / Run All )**, все ячейки будут выполнены по очереди от первой до текущей.
#
# Значения переменных, накопленные после выполнения кода, можно сбросить. Для этого выберите **( Kernel / Restart )** или кликните **( ⟳ Restart )** на панели сверху.
#
# **Упражнение.** Заполните пропуск в следующей ячейке так, чтобы после выполнения кода значение переменной `c` стало равным `8` . Проверьте свое решение, выполнив код ячейки.

# %%
z = 2 # заполните пропуск здесь
c = SumSquare(z, a)
c
# Out:
# 8

# %% [markdown]
# ##  Задание 3. Красивый текст в тетрадках

# %% [markdown]
# Jupyter позволяет форматировать текст красиво. Например, таблица из первой темы будет выглядеть так:
#
# | Язык                     | Доля сайтов в топ 10 млн. | Носители, млн. | Говорящие, млн. |
# |--------------------------|-----------------|--------------------|-------------|
# | Английский               | 53.90%          | 378.2              | 1121        |
# | Русский                  | 6.10%           | 153.9              | 264.3       |
# | Немецкий                 | 6.00%           | 76                 | 132         |
# | Испанский                | 4.90%           | 442.3              | 512.9       |
# | Французский              | 4.00%           | 76.7               | 284.9       |
# | Японский                 | 3.40%           | 128.2              | 128.3       |
# | Португальский            | 2.90%           | 222.7              | 236.5       |
# | Итальянский              | 2.40%           | 64.8               | 67.8        |
# | Персидский               | 2.00%           | 60                 | 110         |
# | Польский                 | 1.80%           | 39.6               | 40.3        |
# | Китайский | 1.70%           | 908.7              | 1.107       |
# | Датский                  | 1.20%           | 22                 | 28          |
# | Турецкий                 | 1.20%           | 78.5               | 78.9        |
# | Чешский                  | 1.00%           | 10.4               | 10.6        |
#
# А вот как выглядят в Jupyter Notebook таблицы из файлов *.csv*, загруженные в библиотеку Pandas:

# %%
import pandas as pd
df = pd.read_csv('/datasets/drive-data.csv')
df
# Out:
#              Модель Категория  Количество  Стоимость за минуту
# 0    Renault Kaptur    эконом         200                  5.0
# 1           Kia Rio    эконом         300                  5.0
# 2       Skoda Rapid    эконом         150                  5.0
# 3           VW Polo    эконом         100                  5.0
# 4           Audi Q3   комфорт          30                  7.1
# 5           Audi A3   комфорт          15                  7.1
# 6       Genesis G70   комфорт          50                  8.5
# 7     Mercedes E200    бизнес          90                 12.9
# 8          BMW 520i    бизнес          60                 12.9
# 9     Porsche Macan     огонь           5                 35.0
# 10  Porsche Carrera     огонь           2                 60.0

# %% [markdown]
# Здесь мы специально не стали вызывать функцию `print(df)`. Без неё вывод таблицы получается красивее.
#
# Jupyter Notebook умеет показывать и очень большие таблицы. Посмотрите, что получается:

# %%
big_df = pd.read_csv('/datasets/music-data-2.csv')
big_df
# Out:
#            ID  total play                                  artist  \
# 0    BF6EA5AF   92.851388                              Marina Rei
# 1    FB1E568E  282.981000                            Stive Morgan
# 2    FB1E568E  282.981000                            Stive Morgan
# 3    EF15C7BA    8.966000                                     NaN
# 4    82F52E69  193.776327                                  Rixton
# 5    4166D680    3.007000  Henry Hall & His Gleneagles Hotel Band
# 6     F4F5677    0.100000                                     NaN
# 7    386FE1ED  211.880000                                     NaN
# 8    A5E0D927    3.161000                   Andrew Paul Woodworth
# 9    E9E8A0CA  274.390000                            Pillar Point
# 10   D3DD8D00    8.836000                          Steve Campbell
# 11   596A4517    0.000000                            David Civera
# 12   2E50EDF9  245.040000                            Lumipa Beats
# 13   79D2876C    2.000000                         Henning Wehland
# 14    5A3095E    0.000000                                     NaN
# 15   96DA13A1    0.000000                            Пётр Каледин
# 16   4023830D   46.885000                                ChinKong
# 17   AEAEF451   15.000000                               Albatraoz
# 18   285648EF    0.100000                              Pugs Atomz
# 19   34811AC9    7.000000                               Zak Moore
# 20   892E9835  219.190863                         Kendra Springer
# 21   46EB28CD  254.862000                        Nathalie Cardone
# 22   919EFA26  272.039167                                 Snowday
# 23   A76F54E1   72.389680                                  Swords
# 24   94E73621    8.109446                     Montezuma's Revenge
# 25   13C442BF  217.000000                                     NaN
# 26   C4AF055B    0.000000                                     NaN
# 27   A6D6DBE7  208.822833                     Музыка для изучения
# 28   9C97ECE2  214.256327                                  A-Life
# 29   DD08E7D1   27.164889                          Peter Holzmann
# ..        ...         ...                                     ...
# 969  4E6B5643    0.000000                             Rayze1Music
# 970  C0FC68D7    9.408249                          Yone Rodríguez
# 971  245F9CDA  212.902000                        The Soul Surfers
# 972  EE625DC8    1.205000                     Los Hermanos Moreno
# 973  AF17B25F  311.666939                             Eric Krasno
# 974  E35E3A35    1.000000                             Espoir 2000
# 975  EAFE863C  197.459592                                 peratus
# 976  92492903    1.777100                             Steve Isles
# 977   8ED7690  392.310000                         Jonathan Yandel
# 978  9EBDDBA6    7.069000                                     NaN
# 979  A5F623CE   42.861888                                 Hard On
# 980  51DFF901    6.465000                                DJ Quick
# 981  DE0231FA    0.100000                                     NaN
# 982  B9CC18E2  160.757542                               Ben Frost
# 983  75504E9B  248.616000                            Behzad Leito
# 984  225F36B7  219.939000                              Katy Perry
# 985  93260E5A  335.853000                                     NaN
# 986  4AB530D4    0.000000                         Emilio Magnotta
# 987   2B60974    5.594000                                  Kitten
# 988  6AF9C9D6  367.000000                            Soap Bubbles
# 989  2AEAB881   80.501417            Pro Arte Orchestra Of London
# 990  EA093908  284.351000                                Venera 4
# 991  91D42B3F  104.741193                               Таня BerQ
# 992  9B024BB6  347.350204                                    Dore
# 993  7341155F    5.000000        Gregorian feat. Amelia Brightman
# 994  5C9F8629   63.000000                                     NaN
# 995  DDF57113  255.582041                             X-Tralounge
# 996  A3308EC5  146.442188                               Andy Hunt
# 997  F80EF638  438.883265                                     NaN
# 998  97D3BB0F    0.100000                                 Duceman
#
#             genre                                              track
# 0             pop                                             Musica
# 1         ambient                                        Love Planet
# 2         ambient                                        Love Planet
# 3           dance                                Loving Every Minute
# 4             pop                             Me And My Broken Heart
# 5            jazz                                               Home
# 6    classicmetal                                                NaN
# 7      electronic                                            Riviera
# 8             pop               The Name of This Next Song Is Called
# 9           indie                                               Dove
# 10           jazz                                        Morning Dew
# 11            pop                                            Bye Bye
# 12         hiphop                                              Cludo
# 13            pop                                 Räuber und Gendarm
# 14            NaN                                                NaN
# 15         spoken                      Пойти и не вернуться. Глава 1
# 16          dance                                          Live Life
# 17            pop                                        General Zod
# 18          dance                                            No Love
# 19          dance                                          Feel Good
# 20            new                                             Sonora
# 21          latin                                      Hasta Siempre
# 22          dance                                           Patterns
# 23          indie                                I Didn't Understand
# 24   extrememetal                                My God Is a Bad Cop
# 25          dance                                         Lightspeed
# 26            NaN                                                NaN
# 27   instrumental                            Инструментальная музыка
# 28          dance                                      Don't Hurt Me
# 29      classical  The Seasons Op. 37A  (August  The Harvest): VI...
# ..            ...                                                ...
# 969        hiphop                                             Dreams
# 970         latin                                   Cho Juan Perenal
# 971          funk  You Can Run (But You Can't Hide) From My Love ...
# 972         latin                                        Bochinchosa
# 973          rock                                           Roll Out
# 974         world                                           Eléphant
# 975          rock                                              orion
# 976   soundtracks                                              Focus
# 977     classical               Metamorphosis Pt. 1: The Golden Cage
# 978       dubstep                                            Kill Em
# 979          rock                                        Brown Sugar
# 980        hiphop                                             Wiggle
# 981           NaN                                                NaN
# 982   soundtracks                                             Shield
# 983        hiphop                                      Oon Bala Sari
# 984           pop                                          Ur So Gay
# 985          rock                         We're All In This Together
# 986         world                                          Rosamunda
# 987   alternative                                            Secrets
# 988         dance                                           We Party
# 989         films                             Desplat: Winter Nights
# 990   alternative                                            Eidôlon
# 991           pop                                  Спасибо за любовь
# 992       ambient                                        Sexy Groove
# 993           pop                                    Moment of Peace
# 994    electronic                                    Feeling Liberty
# 995    electronic                                             Lizard
# 996          hard                                     Reconciliation
# 997           psy                                    Inside the Mind
# 998        hiphop                                     Under Pressure
#
# [999 rows x 5 columns]

# %% [markdown]
# Для оформления текста в Jupyter Notebook используется язык разметки [Markdown](https://ru.wikipedia.org/wiki/Markdown). К примеру, перечислить колонки таблицы можно так:
# - `Модель`
# - `Категория`
# - `Количество`
# - `Стоимость за минуту`

# %% [markdown]
# ## Задание 4. Как аналитики используют Jupyter Notebook

# %% [markdown]
# Завершив проект, вы сможете сохранить тетрадку в файл формата *.ipynb*. Затем открыть его на другом компьютере в Jupyter, поделиться с коллегами, поместить в портфолио. Чтобы сохранить тетрадку, нажмите **( File / Download as... )**.
#
# Jupyter так популярен, потому что в нём удобно просматривать код и результаты его исполнения, а также демонстрировать работу коллегам.
